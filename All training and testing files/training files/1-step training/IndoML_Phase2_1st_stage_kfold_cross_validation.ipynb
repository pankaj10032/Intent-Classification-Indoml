# %% [markdown]
# # **Installing the dependencies**

# %%
# !pip install transformers torch
# Out:
# Collecting transformers
#   Downloading transformers-4.34.1-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 52.6 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.1.0+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.4)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 36.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 60.2 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 78.3 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.1.0)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 28.4 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.17.3 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.34.1

# %%
# !pip install -U SentencePiece
# Out:
# Collecting SentencePiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.7 MB/s eta 0:00:00
# Installing collected packages: SentencePiece
# Successfully installed SentencePiece-0.1.99

# %%
# !pip install accelerate -U
# Out:
# Collecting accelerate
#   Downloading accelerate-0.23.0-py3-none-any.whl (258 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu118)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.17.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.23.0

# %%
CUDA_LAUNCH_BLOCKING=1 # to stop cuda blocking

# %% [markdown]
# # **Connecting google colab to drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Importing the dependencies**

# %%
import json
import random
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import torch
from transformers import BertTokenizer, BertForSequenceClassification
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import RobertaTokenizer, RobertaForSequenceClassification, T5Tokenizer, T5ForSequenceClassification,TrainingArguments, Trainer

# %% [markdown]
# ## Data format
#
# 2 json files - `surprise.data` contains utterances, `surprise.solution` contains corresponding intents
#
# Format of `surprise.data`
#
# ```json
# {"indoml_id": "surprise|11109", "id": "11109", "utt": "Can I make a reservation at Buffalo Wild Wings?"}
# {"indoml_id": "surprise|11051", "id": "11051", "utt": "Can I book a table for tonight at Bella Vita?"}
# ....
# ```
#
# Format of `surprise.solution` (contains 150 labels)
#
# ```json
# {"indoml_id": "surprise|11109", "intent": "accept reservations"}
# {"indoml_id": "surprise|11051", "intent": "accept reservations"}
# ....
# ```

# %% [markdown]
# # **Loading the data and solution of the surprise dataset**

# %%
# Load the data from the JSON files
with open('/content/drive/MyDrive/intent_classification_It_bombay/surprise_data/surprise.data', 'r') as data_file:
    data = [json.loads(line) for line in data_file] # converting string to object using json.loads

with open('/content/drive/MyDrive/intent_classification_It_bombay/surprise_data/surprise.solution', 'r') as solution_file:
    solutions = [json.loads(line) for line in solution_file] # converting string to object using json.loads

# with open('/content/drive/MyDrive/Intent_classification_IIT_BOMBAY/Dataset/massive_test_phase2_data/massive_test.data', 'r') as test_file:
#     test = [json.loads(line) for line in test_file]

# %%
print(data[0]) # data of the surpirse dataset having id and the utterances
# Out:
# {'indoml_id': 'surprise|11109', 'id': '11109', 'utt': 'Can I make a reservation at Buffalo Wild Wings?'}

# %%
print(solutions[0]) # Solutions of the surpise dataset having id and intent for the previous teerances
# Out:
# {'indoml_id': 'surprise|11109', 'intent': 'accept reservations'}

# %%
# Create a dictionary to map indoml_id to intents
intent_map = {item['indoml_id']: item['intent'] for item in solutions}

# Split data into train and test sets (2:1) stratified by intent
indoml_ids = [item['indoml_id'] for item in data]
intents = [intent_map[indoml_id] for indoml_id in indoml_ids]
"""utterances(features) for the dataset"""
utt = [item['utt'] for item in data]

num_classes = len(set(intents))
print("Number of classes")
print(num_classes)

# """Splitting the dataset into train and test set"""
# train_data, test_data, train_labels, test_labels = train_test_split(
#     utt, intents, test_size=0.25, random_state=42, stratify=intents
# )
# Out:
# Number of classes
# 150

# %%
intents
intents_set=set(intents) # basically represent the total no. of disntics intents(labels) in our surprise dataset(150)
print(intents_set)
len(intents_set)
# Out:
# {'international visa', 'tire change', 'application status', 'apr', 'tell joke', 'gas', 'rewards balance', 'account blocked', 'travel notification', 'flight status', 'current location', 'pto request status', 'credit limit', 'reminder update', 'change language', 'transfer', 'change volume', 'tire pressure', 'text', 'sync device', 'calendar update', 'roll dice', 'timer', 'plug type', 'food last', 'make call', 'meeting schedule', 'calculator', 'recipe', 'card declined', 'time', 'freeze account', 'change accent', 'rollover 401k', 'thank you', 'smart home', 'spending history', 'change user name', 'who made you', 'last maintenance', 'book flight', 'report lost card', 'restaurant reviews', 'date', 'calendar', 'schedule maintenance', 'change speed', 'user name', 'traffic', 'expiration date', 'nutrition info', 'min payment', 'reminder', 'restaurant suggestion', 'ingredient substitution', 'next holiday', 'pto request', 'ingredients list', 'do you have pets', 'what can i ask you', 'exchange rate', 'new card', 'travel suggestion', 'pto used', 'oil change how', 'bill balance', 'calories', 'repeat', 'transactions', 'book hotel', 'pin change', 'oil change when', 'pto balance', 'directions', 'todo list', 'what song', 'cancel reservation', 'gas type', 'share location', 'update playlist', 'alarm', 'greeting', 'mpg', 'insurance', 'confirm reservation', 'shopping list update', 'distance', 'how busy', 'cancel', 'car rental', 'damaged card', 'lost luggage', 'order', 'next song', 'restaurant reservation', 'routing', 'schedule meeting', 'fun fact', 'what are your hobbies', 'pay bill', 'carry on', 'vaccines', 'maybe', 'interest rate', 'play music', 'flip coin', 'travel alert', 'report fraud', 'todo list update', 'goodbye', 'who do you work for', 'definition', 'credit score', 'insurance change', 'taxes', 'reset settings', 'payday', 'where are you from', 'meaning of life', 'improve credit score', 'meal suggestion', 'credit limit change', 'redeem rewards', 'shopping list', 'timezone', 'accept reservations', 'order status', 'what is your name', 'international fees', 'balance', 'change ai name', 'weather', 'cook time', 'whisper mode', 'uber', 'direct deposit', 'measurement conversion', 'bill due', 'income', 'no', 'translate', 'find phone', 'order checks', 'jump start', 'are you a bot', 'replacement card duration', 'spelling', 'w2', 'yes', 'how old are you'}
# 150

# %%
labels_list=[]
for label in solutions:
    labels_list.append(label['intent'])
unique_labels_list=[]
for x in labels_list:
    if x not in unique_labels_list:
        unique_labels_list.append(x)
# unique_labels_list, len(unique_labels_list)

label2id={}
id2label={}
for i, label in enumerate(unique_labels_list):
    label2id[label]=i
    id2label[i]=label

# %%
intents_integar = [label2id[label] for label in intents]

# %%
len(intents_integar), intents_integar[0:5],intents_integar[-5:]
# Out:
# (2248, [0, 0, 0, 0, 0], [149, 149, 149, 149, 149])

# %%
# utt

# %% [markdown]
# #**Applying kfold cross validation on the our dataset**

# %%
"""we have utt has our features and labels(intent) converted into integar using label2id is our labels.
then we have converted our features(intent) or X into numpy array and also converted intents_integar into numpy array because we c
can apply kfold  only on the numpy arrays.

After then we have made 4 nump arrays train_data_kfold,train_labels_fold and other same 2 for test set splitted from training set we have taken 5 fold,
it means our fior every fold our training dataset will be first 80% dataset splitting randomly  by applying shuffle=True during kfold and remaining 20% of the dataset will be test set/

Then for 2nd(another) fold we have another 80% of the total dataset will bve training dataset and remaining 30% will be test set."""
# import numpy as np
# from sklearn.model_selection import KFold

# X = np.array([[1, 2], [3, 4], [1, 2], [3, 4]])

# y = np.array([1, 2, 3, 4])
# kf = KFold(n_splits=2)

# for train_index, test_index in kf.split(X):
#     print("TRAIN:", train_index, "TEST:", test_index)
#     X_train, X_test = X[train_index], X[test_index]
#     y_train, y_test = y[train_index], y[test_index]

# X_train, y_train, X_test, y_test

import numpy as np
from sklearn.model_selection import KFold
train_data_kfold=[]
test_data_kfold=[]
train_labels_kfold=[]
test_labels_kfold=[]
X=np.array(utt)
y=np.array(intents_integar)
# y = intents_integar
kf = KFold(n_splits=5, shuffle=True)
print(kf)
print(type(kf.split(X)))
print("**")
for train_index, test_index in kf.split(X):
    print("TRAIN:", train_index, "TEST:", test_index)
    train_data, test_data = X[train_index], X[test_index]
    train_data_kfold.append(train_data)
    test_data_kfold.append(test_data)
    print('**')
    train_labels, test_labels = y[train_index], y[test_index]
    train_labels_kfold.append(train_labels)
    test_labels_kfold.append(test_labels)
# Out:
# KFold(n_splits=5, random_state=None, shuffle=True)
# <class 'generator'>
# **
# TRAIN: [   0    2    3 ... 2244 2245 2247] TEST: [   1    6    9   11   17   23   28   29   33   35   42   45   52   67
#    72   73   90   93   94   95  108  112  129  134  140  146  148  160
#   165  169  182  185  186  192  193  195  203  207  208  212  216  230
#   237  241  259  261  269  283  285  295  302  309  313  314  315  322
#   326  328  340  353  354  359  360  361  363  364  365  367  379  383
#   384  390  400  409  411  413  425  431  435  436  444  446  450  452
#   454  458  459  467  469  475  484  490  507  509  517  518  521  525
#   527  536  540  554  565  572  576  579  586  587  589  594  597  604
#   609  612  614  621  622  623  634  640  641  648  654  656  657  661
#   665  667  685  687  694  697  698  699  700  703  709  710  717  726
#   730  736  740  743  744  748  750  754  757  760  761  771  774  775
#   779  783  787  788  795  799  806  818  823  837  843  846  854  856
#   862  864  865  866  871  904  913  916  918  928  929  939  940  944
#   955  956  960  962  967  968  972  979  980  987  991  993 1003 1005
#  1010 1013 1014 1016 1024 1030 1038 1044 1051 1059 1061 1065 1069 1070
#  1074 1083 1094 1100 1102 1104 1109 1113 1116 1127 1131 1134 1138 1139
#  1142 1143 1144 1146 1150 1153 1156 1158 1161 1169 1171 1175 1176 1182
#  1198 1203 1208 1209 1212 1216 1227 1228 1235 1241 1247 1260 1262 1263
#  1264 1278 1283 1288 1289 1294 1300 1308 1314 1317 1325 1329 1342 1344
#  1347 1348 1361 1365 1368 1369 1379 1384 1391 1392 1397 1404 1410 1415
#  1423 1424 1425 1429 1431 1438 1440 1441 1442 1449 1451 1452 1454 1465
#  1472 1476 1484 1494 1499 1505 1511 1518 1523 1525 1540 1542 1563 1576
#  1583 1584 1585 1586 1588 1593 1599 1602 1606 1609 1613 1619 1628 1631
#  1633 1645 1649 1656 1658 1660 1674 1686 1692 1693 1699 1714 1723 1735
#  1740 1741 1746 1747 1748 1750 1752 1755 1760 1761 1765 1766 1767 1769
#  1777 1790 1791 1792 1798 1806 1809 1812 1813 1815 1816 1817 1818 1824
#  1828 1829 1834 1837 1839 1846 1857 1859 1863 1866 1873 1878 1884 1885
#  1887 1892 1900 1903 1907 1910 1913 1915 1918 1930 1934 1938 1950 1959
#  1962 1970 1971 1975 1979 1981 1983 1984 1986 1987 1990 2006 2007 2024
#  2026 2030 2038 2041 2051 2054 2057 2061 2073 2076 2080 2082 2084 2094
#  2098 2100 2102 2103 2106 2111 2118 2129 2132 2138 2139 2143 2157 2172
#  1661 1663 1672 1680 1681 1682 1689 1700 1704 1706 1712 1716 1720 1721
#  1732 1738 1749 1757 1759 1768 1770 1773 1776 1781 1783 1785 1789 1795
#  1797 1801 1807 1832 1835 1853 1858 1861 1867 1868 1869 1876 1877 1890
#  1894 1896 1899 1901 1906 1921 1922 1923 1926 1936 1949 1951 1968 1972
#  1985 1991 1992 1996 1997 2003 2004 2005 2009 2021 2022 2032 2035 2042
#  2044 2052 2053 2055 2058 2059 2065 2069 2070 2074 2081 2086 2087 2092
#  2095 2097 2099 2104 2105 2108 2117 2119 2124 2146 2161 2162 2165 2167
#  2169 2176 2178 2181 2184 2185 2192 2193 2205 2234 2235 2236 2242 2243
#  2247]
# **

# %%
train_data_kfold, train_labels_kfold
# Out:
# ([array(['Can I make a reservation at Buffalo Wild Wings?',
#          'Does the Cheesecake Factory take reservations?',
#          'Do they take reservations at Outback Steakhouse in Las Vegas?',
#          ..., "Oh, without a doubt, that's absolutely true",
#          "Absolutely, I couldn't agree more!", "That's a superb solution!"],
#         dtype='<U226'),
#   array(['Can I make a reservation at Buffalo Wild Wings?',
#          'Can I book a table for tonight at Bella Vita?',
#          'Does the Cheesecake Factory take reservations?', ...,
#          "Absolutely, I couldn't agree more!", "It's a wonderful notion!",
#          "That's a superb solution!"], dtype='<U226'),
#   array(['Can I book a table for tonight at Bella Vita?',
#          'Does the Cheesecake Factory take reservations?',
#          'Do they take reservations at Outback Steakhouse in Las Vegas?',
#          ..., "Absolutely, I couldn't agree more!",
#          "It's a wonderful notion!", "That's a superb solution!"],
#         dtype='<U226'),
#   array(['Can I make a reservation at Buffalo Wild Wings?',
#          'Can I book a table for tonight at Bella Vita?',
#          'Does the Cheesecake Factory take reservations?', ...,
#          "indeed, that's what I was told!", "It's a wonderful notion!",
#          "That's a superb solution!"], dtype='<U226'),
#   array(['Can I make a reservation at Buffalo Wild Wings?',
#          'Can I book a table for tonight at Bella Vita?',
#          "does chili's take reservations?", ...,
#          "Oh, without a doubt, that's absolutely true",
#          "Absolutely, I couldn't agree more!", "It's a wonderful notion!"],
#         dtype='<U226')],
#  [array([101, 101, 101, ..., 121, 121, 121]),
#   array([101, 101, 101, ..., 121, 121, 121]),
#   array([101, 101, 101, ..., 121, 121, 121]),
#   array([101, 101, 101, ..., 121, 121, 121]),
#   array([101, 101, 101, ..., 121, 121, 121])])

# %%
test_data_kfold, test_labels_kfold
# Out:
# ([array(['Can I book a table for tonight at Bella Vita?',
#          'Can I check availability and make a reservation online?',
#          'Does Buffalo Wild Wings take reservations for sports games',
#          'Does Olive Garden in San Francisco take reservations?',
#          'what caused the sudden suspension of my business account without prior notice?',
#          "Can't believe I got locked out of my own account without any notice!",
#          'Can someone explain why my investment account has been frozen?',
#          "I can't seem to access my funds due to an unexpected restriction on my account.",
#          'Set an alarm on your watch for 12 pm next week.',
#          "Set two alarms for me, one at 8 am and another at 12 pm, so I don't miss my important deadlines today.",
#          'Set two alarms for 7 am and 12 pm so I can have enough time to prepare for work and lunch respectively.',
#          'Could you please tell me whether my visa application has been approved or denied?',
#          'I would appreciate it if someone could inform me about the progress of my Chase application.',
#          'how do I calculate my apr on my discovery card?',
#          'could you please provide me with the apr details of my credit card?',
#          'Could you please tell me the apr of my credit card? I want to stay on top of my finances and avoid any surprise charges.',
#          'How do I ensure that my spending is in line with my income, so I can maintain a stable financial position?',
#          "It's important to maintain a balance between short-term goals and long-term aspirations.",
#          'how much does my credit card debt currently weigh against my budget?',
#          'Can you tell me my current bank balance so I can make informed financial decisions?',
#          'How much am I expected to pay towards my student loans this month?',
#          'Could you please tell me how much I owe on my Time Warner Cable account?',
#          'what happens if i forget to pay my property tax bill?',
#          'What time of the month does my gym membership bill usually come due?',
#          'what airline has flights round trip from jfk to lga on march 15 for under $400?',
#          'Could you please book a flight from Houston to Austin on March 17th for less than $250?',
#          'Could you please book a one-way flight from Houston to Chicago on May 15th for under $200',
#          'I need a hotel reservation in Denver from December 1st to December 7th',
#          'what is 15 plus 12?', 'what is 7 times 8?',
#          'Can you give me an overview of my March 15th calendar',
#          'Can you please show me my schedule for the rest of the month?',
#          'Can you please remind me of everything I have scheduled for March 15?',
#          "What time is my doctor's appointment on my calendar for today?",
#          'Did I add the party to my Google Calendar?',
#          'I would like to cancel my reservation for tonight.',
#          'I need to transfer my conference call to tomorrow morning.',
#          'can you please move the team lunch from friday to wednesday this week?',
#          'Remove the football game from my calendar.',
#          'how many calories are in a bag of potato chips?',
#          'how many calories are in a serving of stir-fry vegetables?',
#          'Could you please cancel my hotel reservation?',
#          "I need you to stop whatever you're working on right now.",
#          'Kindly eliminate my booking for three at The Restaurant at Meadowood.',
#          'can I pick up my rental car at the airport in chicago?',
#          'Can you provide me with information on renting a car in San Francisco?',
#          'Can you help me locate a rental car agency in Denver for March 15 to 19?',
#          "I'm curious about the reason behind my card being rejected at the grocery store yesterday.",
#          'Kindly provide information regarding the carry-on limitations for Virgin America.',
#          'Are there any weight limits for carry-on bags on Turkish Airlines?',
#          'can you talk like a Canadian?',
#          'try on a Boston brogue for size.',
#          "I'd like to hear your voice in an Australian accent, mate!",
#          'Could you please shift to a deeper, more resonant male voice?',
#          'May I modify your moniker to something more fitting?',
#          "i have a feeling that 'zelda' would suit you better.",
#          'can i suggest a few alternative names for you?',
#          'i think it would be great if we could change your name to something funnier.',
#          'Can you communicate with me in Japanese?',
#          "I'm afraid I can't follow what you're saying; you're moving too quickly for me. Could you slow down?",
#          'I struggle to follow your words when you talk quickly; kindly adjust your tone accordingly.',
#          'Your fast speech makes it challenging for me to understand your message; could you please modify your tone?',
#          'Could you kindly update my profile with my new name, Emily?',
#          'I wish you could refer to me as Charlotte instead of Benjamin.',
#          "I'd be happy with any nickname you choose!",
#          'My new name is Ruby, please use it moving forward.',
#          'you can address me as samantha.',
#          "I'd love it if you could start referring to me as Ava instead of Amelia.",
#          'increase volume to 4)', 'can you turn this down)',
#          'please adjust your settings)',
#          'can you confirm my reservation for 4pm at Red Lobster?',
#          "Can you please let me know if I have a reservation for two at the French bistro for Valentine's Day dinner?",
#          'how long does it take to sauté onions?',
#          'how long should I bake potatoes?',
#          'how long should I roast the sweet potatoes for?',
#          'how high is my credit limit for my bank of the west card?',
#          'Can you please provide me with information regarding my credit limit on my Bank of America card',
#          'How do I go about changing my credit limit on my Citi card?',
#          'Would it be possible to increase my credit limit to $750?',
#          'Is it possible to get a higher credit limit on my barclays credit card?',
#          'Can I increase my credit limit on my Bank of America Core® Secured credit card?',
#          'What factors affect my credit score?',
#          'Can I use my credit score to negotiate better interest rates on loans?',
#          'How do I find out my credit score?',
#          'Can you help me dispute errors on my credit report?',
#          'Is there a way to see my credit score without affecting it?',
#          'Can you please update my current location on the map so I can track my progress',
#          'Can you give me directions to my current location?',
#          'How can I find my current location on a map?',
#          'I left my credit card on a beach towel and it got sand-blasted beyond recognition.',
#          'my card fell apart after being exposed to rain; can i get a new one?',
#          'What is the current date?', 'what is the date?',
#          'Can you provide a detailed explanation of the concept of "patriarchy"?',
#          "What is the definition of 'eco-friendly'?",
#          'can you give an example of existentialism in practice?',
#          'I require assistance in configuring direct deposit for my wages.',
#          'I want to arrange direct deposit for my Chase checking account.',
#          "I'm considering switching to direct deposit for my paycheck. Can you give me an overview of the process and any potential advantages?",
#          'could you please provide instructions on how to reach the nearest metro station?',
#          "What's the best way to get to Times Square from JFK airport?",
#          'how far is it to the next city?',
#          'Do you have many kinds of pets at your home?',
#          'How many paws do you have under your roof?',
#          'Are there any little critters that brighten up your day?',
#          'convert 5000 japanese yen into us dollars.',
#          "what's the exchange rate between australian dollars and indian rupees?",
#          'how much is 1000 swiss francs worth in us dollars?',
#          'how much is 500 pounds in canadian dollars?',
#          'how much is 1000 singapore dollars in us dollars',
#          'How long does it take for a new credit card to arrive after I request an expedited replacement?',
#          'how long can i continue using my old phone before it becomes obsolete?',
#          'Can you tell me when my debit card is due to expire?',
#          'Tell me when my Discover card will reach its expiration date.',
#          "I'm having trouble finding my phone - Can you assist me in locating it?",
#          "I'm having trouble discovering my phone; would you be able to help?",
#          'Have you seen my phone anywhere?',
#          'could you please tell me when my flight is expected to arrive',
#          'Can you please inform me about the current status of my American Airlines flight?',
#          'What is the ETA of my upcoming flight?', 'flip this bitcoin.',
#          "let's make this decision easy with a coin toss.",
#          'The anticipation of the coin flip adds an extra layer of excitement to this moment.',
#          "It's time to find out which side the coin will land on!",
#          'how long after opening can you still consume yogurt?',
#          'how long does ground turkey last in the fridge if not frozen?',
#          'how long does a bag of frozen vegetables last in the freezer?',
#          'Kindly put a hold on my checking account until further notice.',
#          'I would like to request that my account be temporarily locked to prevent any further transactions.',
#          'Did you know that the Great Barrier Reef is home to over 1,500 species of fish? Tell me some more interesting trivia about marine life',
#          'did you know that the shortest war in history was between Britain and Zanzibar on August 27, 1896?',
#          'elephants have four molars that grow throughout their lifetime.',
#          'The highest mountain in the solar system is Olympus Mons on Mars, which is around three times the height of Mount Everest!',
#          'Did you know that there\'s a species of jellyfish that\'s immortal? The Turritopsis dohrnii, also known as the "immortal jellyfish," can transform its body into a younger state through a process called transdifferentiation.',
#          'Interesting tidbit: The longest word in English without any repeated letters is "pneumonoultramicroscopicsilicovolcanoconiosis," which refers to a lung disease caused by inhaling very fine silica particles.',
#          'Do I have enough fuel to make it to Tampa without stopping?',
#          'Can you tell me how much gas I have left in my tank?',
#          'how much gas does this car hold?',
#          'How much gas does this car hold?',
#          'Is there a specific type of gas that will give me better mileage?',
#          'Nice speaking with you!', 'It was lovely chatting with you!',
#          'until next time, stay awesome!', 'ciao!',
#          'It was good catching up with you!',
#          "Whats up? It's so good to see you!",
#          'hey there! How are you today?', "What's new with you?",
#          'Whats up, buddy? Long time no catch up!',
#          'Hey there! How was your weekend',
#          'how many customers does the coffee shop typically serve during rush hour?',
#          'how many customers are there at buffalo wild wings?',
#          'how long will it take to get a table for two at the bistro?',
#          'how many customers are shopping in the store right now',
#          'How many years have you been around?',
#          'What is the age of the AI?',
#          'How old will you be when you retire?',
#          'Steps to take to achieve a high credit score.',
#          'Can I increase my credit score by paying off debt?',
#          'How does the credit score get hurt?',
#          'How much do I make biweekly from my full-time job?',
#          'Can you please share my income statement for the past quarter?',
#          'would you suggest using quinoa flour instead of wheat flour in a recipe?',
#          "I'm making pad thai, what ingredients do I need?",
#          'Can you walk me through each step of the recipe and highlight the specific ingredients used in each one?',
#          'what are the essential ingredients for making vegan mac and cheese?',
#          "I'd love to learn more about my coverage options.",
#          'How does my health insurance work?',
#          'Can I get travel insurance if I already have health insurance?',
#          'Can you tell me about my current health insurance policy?',
#          'Kindly provide information regarding my health insurance premiums',
#          "I'm considering switching to a different type of insurance (e.g., from auto to homeowners or renters insurance).",
#          'Does my American Express card have any international transaction fees when used in India?',
#          'What are the fees for making purchases with my card in australia?',
#          'do i need a visa to enter the united kingdom if i am from the us?',
#          'I am planning to move to Germany permanently and I want to know if I need a visa.',
#          'do i need a visa to attend a wedding in south africa',
#          'Can I use my passport to enter Mexico without a visa?',
#          'Are there any precautions I should take when jump-starting a car to avoid damaging either vehicle or electrical system?',
#          'Can you provide me with step-by-step instructions on how to jump-start a car',
#          'Can someone walk me through the process of jump starting a vehicle?',
#          "I can't seem to recall when I last had my car's brakes inspected.",
#          'how long ago did i last have my brakes inspected?',
#          "I'm currently sitting in the airport because my luggage didn't arrive with me, and I don't know where it is. Could someone direct me toward the appropriate authorities?",
#          "I've been calling the airline nonstop, but they haven't been able to locate my missing luggage yet, leaving me feeling frustrated and helpless.",
#          "i need to get in touch with united airline's customer service because my suitcase didn't show up after my flight from denver.",
#          'i checked in my luggage on delta flight dl123 but it never arrived at my destination.',
#          "i'm starting to worry that my carry-on might have been left behind in new york.",
#          'i am eager to speak with samantha.',
#          'X is the person I want to contact immediately.',
#          'Can you please call my mother to wish her a happy birthday',
#          'It depends on various factors, maybe some things are just beyond our control.',
#          "I'm not sure if I can give you an accurate answer",
#          'It could be true, but it also might not be.',
#          "What's a hearty and comforting meal that I can make for my family on a cold winter night?",
#          "Do you know any great vegetarian restaurants in the area? I'm craving something plant-based tonight.",
#          'any ideas for a tasty vegetarian meal?',
#          'would love some suggestions for a mediterranean feast!',
#          "I'm in the mood for something light and refreshing, any seafood suggestions?",
#          'how do you define the term "meaningful life"?',
#          'what do you think is the point of it all?',
#          'what would 2 liters be in fluid ounces?',
#          'how many ounces are in a pound?',
#          "Let me check my calendar for today's meetings.",
#          'I need to check my calendar to see if I have any meetings scheduled for today.',
#          'How many meetings do I have scheduled for this week?',
#          'What is the lowest amount I can pay for my student loan installment?',
#          'I would like to know the minimum amount due on my mortgage this month.',
#          'Can you please tell me the minimum payment due on my student loan this month? It would help me plan my budget better.',
#          "can you please let me know my medical bill's minimum payment?",
#          'How much fuel does this car use in cold weather conditions',
#          'What is the overall mpg rating of this vehicle?',
#          "I'd like to obtain a fresh credit card.",
#          'I would appreciate information on how to apply for a Capital One Savor Cash Rewards Credit Card.',
#          'Can you provide information on the different types of credit cards available in the market?',
#          'can you provide details on how to apply for a new credit card online?',
#          'How many days until my next day off?',
#          'When is the next time off for a holiday around here?',
#          'Move on to the next song, if you will.', 'Can we skip this song?',
#          "Let's switch to the next song on the list.",
#          "I'm feeling this song, but let's keep going; what's next?",
#          "I'm looking forward to hearing the next song on this playlist",
#          "I can't let you have that, it's off limits",
#          "no excuses, you're just plain wrong.",
#          "Your idea is flawed; it doesn't stand up to scrutiny.",
#          "That's impossible!", "No way, Jose! That's just crazy talk!",
#          "no offense, but that's incorrect.",
#          'What are the nutritional benefits of eating a bowl of oatmeal?',
#          'Can you give me the nutrition information for a can of coconut milk?',
#          'What are the vitamin C levels of this mixed green salad?',
#          'Can you tell me the approximate number of calories in a cup of cooked brown rice?',
#          'What are the steps involved in changing the oil in my car?',
#          'how often should I change my oil to keep my car running smoothly?',
#          'how can I avoid common mistakes when changing my oil?',
#          'Can you walk me through the process of changing my oil?',
#          'At what interval should I get my oil changed to ensure optimal performance of my vehicle?',
#          'I would like you to buy me a new pair of sneakers.',
#          'I need you to order me a new bike, could you please get one from REI?',
#          'Kindly arrange for me to have a cab pick me up from the airport when I arrive tomorrow.',
#          'Could you please order a set of art supplies from Dick Blick for me',
#          'Kindly assist me in ordering more checkbooks for my Huntington national bank account',
#          "I would appreciate it if you could send me some extra checkbooks so I don't have to worry about running out.",
#          'Can you kindly provide me with some extra checkbooks?',
#          'Kindly inform me when my package will arrive at my doorstep.',
#          "When will my order arrive if it hasn't shown up yet?",
#          'Can you help me pay my rent?',
#          "I've been working hard lately, and I can't wait to see how much I'll be paid this month. It's always a nice surprise.",
#          'How far in advance does my company provide payroll information?',
#          "I'm feeling financially strained and hope my next payday comes soon.",
#          "I'm hoping to save up enough money by payday to treat myself to something special.",
#          'Kindly help me reset my PIN for my PNC Bank savings account.',
#          'Kindly update my PIN for my brokerage account to enhance its security features.',
#          'Can you assist me in updating my ATM card PIN for my Capital One account?',
#          "I received a new debit card, but I can't access my account without my old PIN number; please help me update it",
#          "It's time to rock out with our instruments!",
#          'play something that makes me feel alive.',
#          'Is it necessary to bring a plug adapter when traveling to Moscow?',
#          'Will I need a voltage adapter for my hair straightener in India?',
#          'would i need a plug adapter for my trip to japan?',
#          'How many days of vacation time do I have remaining',
#          'What is my remaining vacation balance?',
#          'Kindly approve my request for a week of vacation in July to recharge and relax.',
#          'Can you please put in a PTO request for me from September 1st to September 3rd?',
#          'I am planning to take a break from work from March 10th to March 17th and would like to request PTO for those dates.',
#          'Can you please put in a PTO request for me from December 15th to December 31st so I can spend quality time with my loved ones during the holidays?',
#          "What's the current status of my vacation days?",
#          'How many days of leave have I utilized so far this year?',
#          'How many sick days have I taken this year?',
#          'I have taken 12 days off work so far using my PTO.',
#          "Can you calculate how many hours I've spent on vacation?",
#          'Can you provide me with a recipe for gluten-free pizza crust?',
#          'Can someone recommend a recipe for homemade granola bars that are gluten-free?',
#          'Where can I find a recipe for chicken fajitas',
#          'How do I go about using my credit card points to purchase a new laptop?',
#          "i'm curious about the different ways i can use my credit card points.",
#          'Can you help me review my to-do list for the day?',
#          'What notes do I have written down that I need to refer to later',
#          'Have I remembered to feed the cat today',
#          'What are the items on my reminder list?',
#          'New reminder, please, to buy milk on the way home.',
#          'Set a reminder to turn off the lights when you leave the room.',
#          'Set a reminder for my meeting with the boss on Friday at 10 am.',
#          'could you kindly remind me to water my plants tomorrow?',
#          'Can you restate that?',
#          "I'd love to hear that again; could you repeat your favorite joke?",
#          'repeat that again)',
#          'Could you please repeat the instructions one more time? I want to make sure I get them right',
#          "I'm having trouble hearing you, could you please repeat what you just said?",
#          "I'm sorry, could you say that again? I got distracted momentarily.",
#          "I'm having trouble hearing you, so could you please repeat what you just said?",
#          'Can I expedite the process of receiving a replacement card if I need it urgently?',
#          'how do i report a fraudulent charge on my bofi federal bank card?',
#          'Someone made a purchase on my account without my authorization.',
#          'I found a strange transaction on my debit card.',
#          "I'm calling to inform you that my Mastercard has gone missing and I need to file a report with the bank right away.",
#          'My TD Bank card has gone missing',
#          'Shall I help you reset your device to its default settings?',
#          "Let's restore the device to its original state.",
#          'I would like to book a table for two at the bistro tonight at 7 PM.',
#          'reserve a table for 4 at the cheesecake factory under the name amy at 9:00 pm tonight.',
#          'Can you please reserve a table for four at the Italian place for Saturday night?',
#          'What are the opinions on Outback Steakhouse?',
#          'How would you describe the service at Ruby Tuesday?',
#          'can i use my citi double cash card rewards to pay off my credit card debt?',
#          'the boss wants us to roll a set of rare 4 sided dice for the big presentation.',
#          'I would love it if you could roll a 10-sided dice for me.',
#          'the game calls for rolling a set of custom 5 sided dice.',
#          'roll a set of collectible 8 sided dice with different designs on each side',
#          'please roll a dice with 7 sides.',
#          "Can you roll a 20-sided die for me? It's a big choice!",
#          "I am eager to learn about the process of transferring my 401k to a new employer's plan.",
#          'I am looking for information on how to roll over my 401k into a Roth IRA to potentially reduce my tax liability in retirement.',
#          'I want to move my retirement funds into an individual retirement account (IRA) to avoid penalties and have more investment options.',
#          "where do i get my bank's routing number from?",
#          'Can you tell me my BB&T routing number for my checking account?',
#          'how do i determine the right routing number for my ubs account?',
#          'can you tell me my suntrust routing number so i can set up automatic payments',
#          'I must arrange a tire rotation service.',
#          "I would like to arrange for my vehicle to be serviced at Joe's Garage.",
#          "Scheduling a battery test is essential for my car's health.",
#          'Let me know when you would like to meet, and I will make sure the conference room is available.',
#          'I need to send my current location to my best friend.',
#          'Kindly inform John of my current location so he can come pick me up from the airport.',
#          'I would love it if you could share my location with my favorite food delivery service, so they can bring me lunch',
#          'Share my location with my sister.',
#          'What else can I add to my shopping list?',
#          'Is olive oil already on my shopping list',
#          'add coffee to my shopping list because I need more for work.',
#          'Could you please turn on the air purifier in the bedroom',
#          'Would you mind turning off the alarm system for tonight',
#          "How do I spell the word 'photography'",
#          'I need to know my average monthly expenditure on groceries over the past year.',
#          'how much did i spend on traveling last quarter?',
#          'Can you please sync my fitness tracker to my phone',
#          'Could you please detach my phone from my camera?',
#          'Would you mind connecting my e-reader to the cloud?',
#          'Could you please connect my fitness tracker to my phone?',
#          'Kindly connect my camera to my computer, please.',
#          'Could you please detach my laptop from my phone?',
#          'Kindly link my smartphone to Wi-Fi.',
#          'Can you explain the different types of tax deductions available to me?',
#          'can you help me calculate my self-employment tax?',
#          'How much do I need to pay in property taxes this year?',
#          'Can you explain the tax benefits of donating to charity?',
#          'How does the tax system work in this country, and how does it affect my personal finances?',
#          "I'd like to know if there are any tax credits or deductions available to me as a small business owner.",
#          "What's the silliest joke you know?",
#          'Tell me a joke about sports',
#          'Ask Lily to text you back later this afternoon to discuss the budget for the marketing campaign.',
#          'ask fred if he prefers receiving messages via phone calls or texts.',
#          'Send a quick message to john about the meeting tomorrow.',
#          'Thanks for being so kind!',
#          'I am grateful for your support; thanks a million!',
#          'Your support means everything to me; thank you.',
#          'Your generosity is truly appreciated; thank you very much.',
#          'Can you please tell me the time in Tokyo?',
#          'What time is it in California?',
#          'What is the current time in London?',
#          'Can you please tell me the time in Tokyo?',
#          'I need to know the time in Los Angeles.',
#          'I urgently require the current time.',
#          'I need a 30-minute timer for my study session.',
#          'Set a reminder for 45 minutes.',
#          'Can you please set a timer for 20 minutes so I can work on this project without interruptions?',
#          'Can you please set a timer for 5 minutes?',
#          'Please set a timer for 40 minutes so I have enough time to cook dinner and eat before my meeting.',
#          'what is the time zone of China?',
#          'The time zone of Italy is what?',
#          'How often should I check my tire pressure?',
#          'How often should I get my tires inspected?',
#          'How long will it take for my tires to wear down to the point where they need to be replaced?',
#          'Is it important to keep track of my tire pressure?',
#          'How can I check the air pressure in my tires',
#          'Do my tires have enough air in them?',
#          "What's the current PSI reading on my tires?",
#          "What's the tire pressure of my car?",
#          'Is there anything important that I might have forgotten to add to my list?',
#          'What exactly am I meant to accomplish today from my to-do list?',
#          'reorganize my task list according to urgency.',
#          'streamline my to-do list for maximum productivity.',
#          'Can you please add the birthday party invitations to my to-do list?',
#          'will you ensure that paying rent is on my to-do list?',
#          'Kindly update my to-do list to reflect that I have completed the "clean the garage" task.',
#          'Are there any road closures or construction affecting traffic nearby?',
#          'can you tell me the traffic conditions on the main road leading to the mall?',
#          'Kindly provide me with the details of my recent purchase from Amazon.',
#          'Can you provide details of my last e-commerce transaction?',
#          'Could you please transfer $20 from my checking to my savings account?',
#          'transfer $50 from brokerage account to retirement account',
#          'send $50 from joint account to single account',
#          "how do you say 'i'm lost' in korean?",
#          'How do they say "I\'m tired" in Korean',
#          'how do i say good luck in german?', 'Safe to travel to Thailand?',
#          'Is it safe to travel to Brazil amidst the ongoing pandemic?',
#          'Check travel alerts for Kenya.',
#          'My family and I are heading to Bali next month, what kind of alerts should we keep an eye out for?',
#          "I want to know if there's a danger of traveling to Mexico.",
#          'can you tell me about the latest travel alerts in japan?',
#          'Can I safely travel to Australia with a valid visa?',
#          "i'm going on a road trip across the usa and need my bank informed of my whereabouts.",
#          "I'm heading to Costa Rica for a yoga retreat next week, so I should notify my bank.",
#          'I need an Uber to get to the airport urgently.',
#          'How much will it cost to take an Uber from LAX to downtown LA?',
#          'I want to book an Uber Black car for my anniversary dinner tonight.',
#          'add single ladies by beyonce to my pop playlist.',
#          'add a playlist for my workout routine with energetic songs.',
#          "add 'Can't Stop the Feeling!' to my 'Feel-Good Playlist'",
#          "Do you have a pet name for me when we're just hanging out?",
#          "What's the name you use when you want to tease me in a playful way?",
#          "What's your preferred name for me?",
#          'What are the recommended vaccinations for travel to France during the summer months',
#          'How many vaccinations do I need to get before traveling to France?',
#          'Can you please tell me how many vaccinations I will have to undergo before traveling to Vietnam?',
#          'What are the common illnesses I should be vaccinated against when leaving the United States?',
#          'Can you please tell me where I can find my lost W-2 form?',
#          'Can someone please guide me on how to retrieve my W2 form?',
#          'What is the average high temperature in Miami during the summer?',
#          'Can you tell me about the humidity level in the area?',
#          'Will there be any sunny days this week?',
#          'What is the weather forecast for this weekend?',
#          'What are the current weather conditions in New York City?',
#          'What is the weather like in Tokyo right now?',
#          "It's always great to learn about people's passions and hobbies!",
#          'what are some of the things you can assist me with?',
#          'Is there a limit to the complexity of questions you can answer',
#          'what are some of the more complex queries you can handle?',
#          "Is there anything you're not able to help me with?",
#          'Who do you go by these days?', 'Can you share your given name?',
#          'can you please inform me of the title of the song currently being played?',
#          "what's the name of the town or city where you were born?",
#          'Where did you develop your unique perspective?',
#          'i need you to whisper this message.',
#          'I suggest we converse softly.',
#          'What department do you primarily work within?',
#          "I don't think I've ever met anyone who works directly for me before!",
#          'who is credited with creating your robotics software',
#          'the person who made you is who',
#          'the story of how you were created is fascinating',
#          'who was responsible for designing your neural network?',
#          'It must have taken a team of brilliant developers to build an AI like you.',
#          'who came up with your neural network architecture?',
#          'which research institute created your language generation capabilities?',
#          'you hit the nail on the head!',
#          "Absolutely, I couldn't agree more!", "It's a wonderful notion!"],
#         dtype='<U226'),
#   array(["does chili's take reservations?",
#          "Set an alarm for 12:30 pm so I don't forget my lunch appointment.",
#          'Can you set an alarm for my work shift starting at 9 am',
#          "I would appreciate it if you could set an alarm for my daughter's soccer game.",
#          'I need an alarm to go off at 10 pm to wind down.',
#          'What is the latest update on my us bank cash+ card application?',
#          'I would like to inquire about the status of my medical school application. Are they still accepting applications?',
#          'Could you please give me an update on the status of my Wells Fargo application?',
#          'Kindly provide me with an update on the status of my visa application.',
#          'Can you tell me the current status of my chase freedom unlimited application?',
#          'Can you tell me the current APR for my US Bank Cash+ Visa Card?',
#          "Can you please provide me with my credit card's apr details?",
#          'How does the APR on my Wells Fargo card compare to other cards in the market?',
#          "I'm impressed by your intelligence; are you a human or a machine?",
#          "It's great chatting with you; do you have feelings too?",
#          "You're so quick to respond; are you a real person or a machine?",
#          "I can't believe you're this helpful!",
#          'How much is left in my savings account after transferring the funds to my checking account?',
#          "Can you please tell me the current balance of my retirement account? I want to make sure I'm saving enough for my future",
#          'How much cash do I have available at the moment?',
#          'Can you please tell me the current balance of my Amazon Prime membership?',
#          'How much is the total amount I need to pay for all my utility bills this month?',
#          'Kindly inform me of the present balance on my AT&T account.',
#          'I need to know when my cable bill is due this month.',
#          'When does my Verizon Wireless bill come due this month?',
#          'please book me a flight from denver to salt lake city on Frontier airlines for next tuesday',
#          'Can you please book me a flight from detroit to cleveland on spirit airlines',
#          'Compare fares for flights from Seattle to Bangkok on Thai Airways and book the cheapest option.',
#          'I want to travel from boston to new york city on wednesday, can you help me find a flight?',
#          'book a flight from Tampa, Fl to Baltimore, Md on February 11, 2019, and return on March 19, 2019.',
#          'I want to book a round-trip flight from Dallas to Houston on Delta Air Lines.',
#          'reserve a flight from Boise to Sacramento on Sunday and return on Wednesday.',
#          'book a flight from minneapolis to milwaukee on wednesday and returning on friday.',
#          'Help me locate a hotel in Chicago with good restaurants nearby.',
#          'Are there any hotels in Paris with Michelin-starred restaurants?',
#          'Would you please find me a hotel in Austin that can accommodate 12 people from September 1st to September 3rd?',
#          'What is the sum of 8 and 7?',
#          'Could you please solve for x in the equation 3x + 5 = 22?',
#          'Is there anything important noted on my calendar for today?',
#          'Can you please remind me of the meeting on my calendar for Wednesday at 2 PM',
#          "Can you tell me what's on my calendar for next Friday?",
#          'Can you please check if I have any meetings scheduled for next week on my calendar?',
#          'What time is my flight on Friday?',
#          'Kindly add the dentist appointment to my calendar for March 15th at 2 pm.',
#          'Remove the football game on September 2nd from my calendar',
#          "Leave the doctor's appointment open on my calendar until further notice.",
#          'Add the fitness class to my calendar every Monday morning.',
#          'how many calories are there in a pear?',
#          'how many calories are in a slice of cheese pizza?',
#          'how many calories are in a slice of watermelon?',
#          'how many calories are there in a cup of unsweetened almond milk?',
#          "I'm afraid I won't be able to finish this task on time, so I'd like to cancel it.",
#          'Halt the ongoing project immediately!',
#          'Disavow any involvement in that endeavor.',
#          'Postpone the meeting until next week.',
#          'Cancel the reservation for Joe and me right now for the Zephers reservation we had booked.',
#          'Please discontinue the reservation I made for two guests at The Blue Lagoon on Saturday night.',
#          'I would like to cancel the reservation for the spa treatment on Monday afternoon.',
#          "I'm not feeling well, so I don't think I'll be able to make it to the appointment today. Would you mind canceling it?",
#          "I'd appreciate it if you could cancel the reservation for the flight we booked last month.",
#          'I would like to cancel my table for 8pm at Bistro Bliss.',
#          'Kindly eradicate my 6:00 PM reservation',
#          'What are the rates for renting a car in Dallas for a period of two weeks starting from March 1st?',
#          'I am interested in renting a luxury car in Los Angeles for my wedding day. Can you provide recommendations?',
#          'I was hoping to get a new TV, but my card was declined at Costco.',
#          'While shopping online, I received an error message saying my card was declined, so I had to use an alternative payment method.',
#          'I want to know why my bank card was not accepted at the mall yesterday afternoon.',
#          'Are there any restrictions on carrying on a stroller on delta flights?',
#          'Does Alaska Airlines allow passengers to bring multiple carry-on bags on a flight?',
#          'What are the dimensions of a carry-on bag that I can bring on a United Airlines flight from Chicago to Denver?',
#          "I'm curious to hear how you sound in a Cockney accent.",
#          "let's experiment with some new vocal patterns!",
#          'I would prefer it if you spoke with a more formal, proper English accent.',
#          'would you prefer if i called you brody',
#          'Can I interest you in a name change to "Astrid"?',
#          'can i call you something different, like ethan?',
#          'how about we rename this ai to something more memorable?',
#          'Can you please change your language to Italian?',
#          'can you switch to english for this conversation?',
#          'Would it be possible for you to speak at a more moderate pace?',
#          'Could you please take your time when speaking?',
#          'Kindly call me Rachel instead of Tom.',
#          'From today onwards, I would prefer to be referred to as Ava.',
#          'I would like you to lower the volume of your voice.',
#          'Could you kindly inform me if I have a reservation at the Thai place for next Wednesday?',
#          'can you confirm if i have a reservation at pizza hut for tonight?',
#          'I would love to have my reservation confirmed for the 15th of this month at 6 pm.',
#          'I would love it if you could confirm my reservation for Saturday evening at The Capital Grille.',
#          'Can you please confirm if I have a reservation for a party of four at 3 pm this Saturday?',
#          'how many minutes should I bake the pizza for?',
#          'how long should I steam broccoli for?',
#          'how long should i cook pasta in boiling water?',
#          'how long does it take to boil water for tea?',
#          'how many minutes should I bake the chicken breasts?',
#          'how long should I braise short ribs?',
#          'Can you please inform me about my credit limit on my capital one card?',
#          'What is my current credit limit on my Discover it cash back credit card?',
#          'I need to know the exact amount of my credit limit so I can plan my expenses better.',
#          'how does my credit limit affect my ability to make purchases?',
#          'I would like to check my Mastercard spending limit, please.',
#          "I'm hoping to get a higher credit limit on my American Express card. Can you make that happen?",
#          'I would appreciate it if you could consider increasing my credit limit on my chase card.',
#          'Is it possible to get a higher credit limit on my Capital One Guaranteed Mastercard',
#          'What is the average credit score in the United States?',
#          'Could you pinpoint my exact location on the map?',
#          'What are my GPS coordinates right now?',
#          'Can you please give me my current location details?',
#          'my child swallowed my credit card and needs medical attention.',
#          "I can't use my ID card because it got wet during the storm last night.",
#          'I discovered that my gift card had been damaged during shipping; can I still use it?',
#          'My card has been damaged by a faulty ATM machine, and I want to file a complaint.',
#          'Can you tell me the date of my birthday?',
#          'What date did you say the package would arrive? Paraphrased sentence: When did you mention the package was expected to arrive?',
#          'in 2 days, what date will it be?',
#          'Can you give me the date of the party we are planning for next month?',
#          'What will the date be 100 days from now?',
#          'explain the definition of bubbly',
#          'what is the definition of perspicacious?',
#          "what is the definition of the term 'ululate'",
#          'What does "resilience" mean in the context of mental health?',
#          'How would you define "ataraxy"?',
#          'Kindly guide me through the steps involved in establishing direct deposit for my child support payments.',
#          "Can you tell me the best way to set up direct deposit for my paycheck? I want to make sure it's done correctly.",
#          'Do you have any recommendations for getting around Manhattan without a car?',
#          'How do I get to the city center from my hotel?',
#          'Can you give me directions to the Metropolitan Museum of Art?',
#          'Can you tell me how to get to the nearest hospital?',
#          'How far is it to the nearest ski resort?',
#          'how long will it take to walk across the desert?',
#          'how far is it to the nearest hospital from my current address?',
#          'how long will it take me to swim to the other side of the lake?',
#          'Are there any scaly or feathered companions in your household?',
#          'How many tails wag when you come home?',
#          'how many Singapore Dollars can I exchange for 500 USD',
#          'what is the exchange rate for australian dollar to us dollar?',
#          "How far in advance can I renew my driver's license?",
#          "Can I renew my driver's license online?",
#          'do i need to update my software before the expiration date?',
#          "I've been looking high and low for my phone without any luck - Can you lend a hand?",
#          "Ugh, I can't believe I misplaced my phone again. Any ideas on how to find it?",
#          'Have you seen my smartphone anywhere?',
#          'Have you seen my phone anywhere recently?',
#          "I'm having trouble locating my phone. Can someone please assist me?",
#          'Kindly provide me with the most up-to-date information regarding my flight status.',
#          'Please let me know if there are any changes to the flight schedule.',
#          'I suggest we flip a coin to choose between these two delicious-looking desserts.',
#          'Flip a coin with a magical property, I win if it lands on tails',
#          'how long does milk last in the fridge if left unopened',
#          'how long can you keep opened jars of pickles in the fridge',
#          'Can you tell me how long the opened jar of jam will last in the pantry before it goes bad?',
#          'How long can I store the soup in the fridge before it spoils?',
#          'I need you to immediately stop all transactions on my account due to a security breach.',
#          'I require your assistance in putting a temporary freeze on my retirement account.',
#          'I need you to immediately suspend all activity on my credit card account until I give you explicit permission to continue.',
#          'Can I make it home from work without stopping for gas?',
#          'Is my gas tank full?', 'Does this take regular unleaded?',
#          'Is there a specific type of gas that my car requires?',
#          'Which type of gas do I need to put in my car?',
#          'What type of fuel does my car require?',
#          "How often should I check my car's gas level?",
#          'What happens if I use the wrong type of gas in my car?',
#          'Talk to you soon!', 'I enjoyed our conversation!',
#          'Take care and stay in touch!', 'Until we meet again; farewell!',
#          'Until we meet again, take care of yourself and keep in touch.',
#          "hallo! how've you been doing?",
#          'good afternoon! How was your weekend?',
#          'Good morning! Hope your day is going great so far!',
#          'how long will I have to wait for a table at Red Robin?',
#          'How crowded does the mall get during the holiday season?',
#          'how busy does the bar area get at happy hour at the local sports pub?',
#          'is there a wait time to get into the cheesecake factory?',
#          'How congested is the area around Starbucks during rush hour?',
#          'how long will it take to get a table at the new sushi spot?',
#          'Tell me your date of birth, AI!',
#          'how long have you existed in this realm?',
#          'when did you first appear on this planet, ai',
#          'For how long have you existed?', 'Can I repair my damaged credit',
#          'What is my annual income?',
#          'I want to know how much I will be earning after my next raise',
#          'Can you tell me my hourly wage?',
#          'can i use olive oil instead of avocado oil in a sauce recipe?',
#          'can i use green tea instead of black tea in a baked good recipe?',
#          'Can I use avocado oil instead of olive oil in cooking?',
#          'What do I need to make a classic paella?',
#          'How does my health insurance work?',
#          'Is my policy transferable if I move to another state?',
#          'I am considering changing my insurance plan to one that provides more flexible coverage options.',
#          'I would like to upgrade my current insurance plan to one that offers more comprehensive coverage.',
#          'I want to switch to a different auto insurance provider.',
#          'I would like to downgrade my insurance plan to save money on premiums while still maintaining adequate coverage.',
#          "I'm interested in learning more about insurance plans available in the market.",
#          'Can you help me compare different auto insurance policies?',
#          'How do I go about switching to a new health insurance provider?',
#          'i would like to purchase additional liability insurance.',
#          'I would like to switch to a different health insurance plan that offers better coverage for mental health services.',
# ...
#          'where should I travel to enjoy the best skiing and snowboarding in North America?',
#          'Can you suggest some fun activities to do in Denver',
#          'Can you please assist me in getting an Uber to the nearest gas station?',
#          'can i get an uber for two people to go to the library?',
#          'Could you please update my electronic playlist with "Tsunami" by Daft Punk?',
#          'add songs I love from different genres to my playlist.',
#          'I want to have "We Are Young" by Fun. added to my "Road Trip" playlist.',
#          "What do you call me when I'm being particularly stubborn?",
#          'I wish you could remember my name!',
#          "What's your preferred nom de plume?",
#          'What is your preferred moniker?',
#          'How about we just stick with your username for now',
#          'what immunizations do i need to get before traveling to australia?',
#          'do i need any vaccinations before traveling to mexico',
#          'do i need any immunizations before traveling to germany?',
#          'How many doses of vaccine will I be required to get before embarking on a trip to Thailand?',
#          "I've been trying to track down my W2 form for weeks; could you please help me locate it?",
#          'Is there a way to expedite the delivery of my W-2 form?',
#          "I'm trying to locate my W-2 form so I can submit it to the IRS before the deadline.",
#          'Could you kindly inform me where to obtain my W2 form?',
#          "Where can I find the form that shows my employer's name and my annual wages for tax purposes?",
#          'Will it be sunny or cloudy tomorrow morning?',
#          'Will there be any thunderstorms tonight?',
#          'Is it going to snow this winter?', 'Will it rain tonight?',
#          'What activities do you enjoy doing during your free time?',
#          'What are some things you find relaxing or entertaining outside of work?',
#          'Can you tell me about your favorite leisure activities?',
#          'I want to learn more about you.',
#          "Can you tell me the name of the song that's playing on Spotify right now",
#          'find out what this song is?', 'what is the song on speaker?',
#          "what's the name of the catchy tune you're jamming to?",
#          'Kindly provide me with the name of the song that is currently being aired.',
#          "What's your hometown known for?",
#          'What corner of the globe did you emerge from?',
#          'What nation do you belong to?',
#          'have you ever lived outside of your current location?',
#          "What's your heritage",
#          'I wish we were in a place where we could whisper our secrets without worrying about being overheard.',
#          "I'm trying to concentrate; could you please whisper?",
#          'I work in the sales department.',
#          "Absolutely! I couldn't agree more!",
#          "Absolutely! I couldn't agree more!",
#          "Of course! That's exactly what I was thinking.",
#          'of course, I understand completely!',
#          "indeed, that's what I was told!", "That's a superb solution!"],
#         dtype='<U226')],
#  [array([101, 101, 101, 101,  66,  66,  66,  66, 117, 117, 117, 137, 137,
#          112, 112, 112,  49,  49,  49,  49, 118, 118,   4,   4,  37,  37,
#           37, 136, 103, 103,  90,  90,  90,  90,  90,  22,  22,  22,  22,
#          105, 105, 130, 130, 131, 141, 141, 141,  28,  61,  61,  19,  19,
#           19,  19,  40,  40,  40,  40,  55,  88,  88,  88,  62,  62,  62,
#           62,  62,  62, 139, 139, 139,  24,  24, 140, 140, 140,  70,  70,
#           36,  36,  36,  36, 122, 122, 122, 122, 122,  93,  93,  93,  73,
#           73, 147, 147, 124, 124, 124,  20,  20,  20,  82,  82, 115,  56,
#           56,  56,  13,  13,  13,  13,  13, 138, 138, 138, 138,  47,  47,
#           47,  15,  15,  15,  74,  74,  74,  74,  10,  10,  10, 125, 125,
#           38,  38,  38,  38,  38,  38,  32,  32,  32,  42,  42,  59,  59,
#           59,  59,  59, 113, 113, 113, 113, 113,  97,  97,  97,  97,  52,
#           52,  52, 132, 132, 132,  41,  41,  87,  33,  33,  33, 145, 145,
#          145, 145, 145,  29,  17,  17, 129, 129, 129, 129,  18,  18,  18,
#          114, 114,  65,  65,  65,  65,  65, 128, 128, 128, 144, 144, 144,
#           98,  98,  98,  98,  98, 104, 104, 111, 111,   0,   0,   0,  11,
#           11,  11,  11,  48,  48,  26,  26,  26,  26,  58,  58,  91,  91,
#           46,  46, 119, 119, 119,   2,   2,   2,   2,   2, 134, 134, 134,
#          134, 102, 102, 102, 102, 102,   8,   8,   8,   8,  43,  43,  43,
#          126,  51,  51,  51,  51,  51,  89,  89,  89,  89,  89,  12,  12,
#          120, 121, 121, 121, 121, 121, 121])])

# %% [markdown]
# #**label encoding- converting labels to numeric values**

# %%
# from sklearn.preprocessing import LabelEncoder
# label_encoder=LabelEncoder()
# intents_int=label_encoder.fit_transform(intents)
# intents_int, intents_int.shape

# %%
# intents
# intents_set=set(intents) # basically represent the total no. of disntics intents(labels) in our surprise dataset(150)
# print(intents_set)
# len(intents_set)

# %%
# id2label={} # id2label mapping
# label2id={} # label2id mapping
# for i, intent in enumerate(intents_set):
#   id2label[i] = intent
#   label2id[intent]=i

# %%
print(list(id2label.items())[:5])
print('\n')
print(list(label2id.items())[:5])
# Out:
# [(0, 'meeting schedule'), (1, 'rollover 401k'), (2, 'user name'), (3, 'what can i ask you'), (4, 'bill due')]
#
#
# [('meeting schedule', 0), ('rollover 401k', 1), ('user name', 2), ('what can i ask you', 3), ('bill due', 4)]

# %% [markdown]
# # **Loading the pretrained intent classification Alexa XLMRoberta model and the tokenizer**

# %%
# Define the BERT model and tokenizer
# keep `ignore_mismatched_sizes=True` so that the classification layer is randomly initialized
# model_name = "cartesinus/bert-base-uncased-amazon-massive-intent"  # Example: You can replace this with the specific RoBERTa variant you want to use
from transformers import XLMRobertaTokenizer, XLMRobertaForSequenceClassification

# model_name = 'qanastek/XLMRoberta-Alexa-Intents-Classification'
# model_name="philschmid/habana-xlm-r-large-amazon-massive" # 91% accuracy on Intent classification base amazon massive
model_name="ibm/roberta-large-vira-intents" # by the IBM on 180 labels
# model_name='neurae/bert-dnd-intents' # trained on 15 intent with achieving an accuracy of 98%
# Initialize the tokenizer
# tokenizer = XLMRobertaTokenizer.from_pretrained(model_name)
tokenizer=RobertaTokenizer.from_pretrained(model_name)
# tokenizer=BertTokenizer.from_pretrained(model_name)

# %%
# Initialize the model
num_classes=150
# model = XLMRobertaForSequenceClassification.from_pretrained(model_name, num_labels=num_classes, ignore_mismatched_sizes=True) # ,output_hidden_states=True
model = RobertaForSequenceClassification.from_pretrained(model_name, num_labels=num_classes, ignore_mismatched_sizes=True)
# model = BertForSequenceClassification.from_pretrained(model_name, num_labels=num_classes, ignore_mismatched_sizes=True)

"""since model have its own id2label mapping and vice versa so, converting them from our id2label and label2id mapping as defined earlier"""
model.label2id=label2id
model.id2label=id2label
# Out:
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at ibm/roberta-large-vira-intents and are newly initialized because the shapes did not match:
# - classifier.out_proj.weight: found shape torch.Size([181, 1024]) in the checkpoint and torch.Size([150, 1024]) in the model instantiated
# - classifier.out_proj.bias: found shape torch.Size([181]) in the checkpoint and torch.Size([150]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from torch.utils.data import DataLoader
batch_size = 32  # Adjust the batch size as needed
# Create PyTorch datasets
class IntentDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: val[idx] for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
train_data_kfold[1]
# Out:
# array(['Can I make a reservation at Buffalo Wild Wings?',
#        'Can I book a table for tonight at Bella Vita?',
#        'Does the Cheesecake Factory take reservations?', ...,
#        "Absolutely, I couldn't agree more!", "It's a wonderful notion!",
#        "That's a superb solution!"], dtype='<U226')

# %%
train_labels_kfold[1]
# Out:
# array([101, 101, 101, ..., 121, 121, 121])

# %% [markdown]
# # **making pytorch datasets for all the foldes by iteraing in range of 5**
#
# # **Also applying dataloader for all the folds**

# %%
train_dataloader_kfold=[]
test_dataloader_kfold=[]
for i in range(5):
  # Tokenize the input training data
  train_encodings = tokenizer(
      list(train_data_kfold[i]),
      truncation=True,
      padding=True,
      max_length=54,
      return_tensors='pt'    #return type is pytorch tensor
  )
  #Tokenizing the input testing data
  test_encodings = tokenizer(
      list(test_data_kfold[i]),
      truncation=True,
      padding=True,
      max_length=54,
      return_tensors='pt'
  )



  train_dataset = IntentDataset(train_encodings, train_labels_kfold[i])
  test_dataset = IntentDataset(test_encodings, test_labels_kfold[i])


  train_dataloader = DataLoader(
      train_dataset,
      batch_size=batch_size,
      shuffle=True  # You can shuffle your data for randomness during training
  )
  test_dataloader = DataLoader(
    test_dataset,
    batch_size=batch_size,
    shuffle=False  # You can shuffle your data for randomness during training
    )
  train_dataloader_kfold.append(train_dataloader)
  test_dataloader_kfold.append(test_dataloader)

# %%
train_dataloader_kfold
# Out:
# [<torch.utils.data.dataloader.DataLoader at 0x7bfb1c77ea40>,
#  <torch.utils.data.dataloader.DataLoader at 0x7bfb1c07c790>,
#  <torch.utils.data.dataloader.DataLoader at 0x7bfb19fbad70>,
#  <torch.utils.data.dataloader.DataLoader at 0x7bfb1c07d540>,
#  <torch.utils.data.dataloader.DataLoader at 0x7bfb19fbaa10>]

# %%
# """Convert labels to numeric values from label2id mapping"""
# train_int_labels = [label2id[label] for label in train_labels]
# test_int_labels = [label2id[label] for label in test_labels]
# test_int_labels[0:5]

# %% [markdown]
# # **initializing training arguments and training the model**

# %%
# # Create a trainer and train the model
# trainer = Trainer(
#     model=model,
#     args=training_args,
#     train_dataset=train_dataset,
#     eval_dataset=test_dataset,
# )

# trainer.train()

# %% [markdown]
# # **Traning the model by iterating over training dataloader**
#
# *Here we will trainn the model not using Training Arguments and Trainer because we have to do some changes in our training.*
#
# **Here we will train the model by iterting over training dataloader and calculating the training loss at the same time and at the same time we will evaluate the same model using model.eval and also calculating the validation loss at the same time**

# %%
# Training arguments
# previous_saved_dir='./intent_classification__'
saved_dir='/content/drive/MyDrive/intent_classification_It_bombay/trained_model_kfold_checkpoints/'
training_args = TrainingArguments(
    output_dir=saved_dir,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=32,
    seed=42,
    # weight-decay=0.01
    # gradient_accumulation_steps=40,
    evaluation_strategy="steps", # use 'epoch' for evaluating every epoch
    logging_steps=10,
    eval_steps=10,
    save_total_limit=5,
    save_steps=15,
    learning_rate=7e-6,
    # warmup_steps=400,
    # weight_decay=0.10,
    # adam_epsilon=1e-7,
    # warmup_steps=400,
    num_train_epochs=2,
    logging_dir='./logs',
)

# %%
import os
import torch
from transformers import AdamW, get_linear_schedule_with_warmup
from transformers import TrainingArguments
from tqdm import tqdm

# Define your model, tokenizer, and other necessary components here
# Make sure your model is moved to the GPU if available

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

# Define the learning rate as a float (e.g., 7e-6)
learning_rate = 7e-6

# Define the number of training epochs for each fold as an integer (e.g., 8)
num_epochs_per_fold = 8

# # Define the number of training epochs as an integer (e.g., 40)
# num_train_epochs = 40

# Create the optimizer
optimizer = AdamW(model.parameters(), lr=learning_rate)

# # Define the number of training steps (you may need to adjust this based on your dataset)
# Calculate the total number of training steps
total_train_steps = len(train_dataloader_kfold[0]) * num_epochs_per_fold

# Define the number of warmup steps (e.g., 10% of the total training steps)
num_warmup_steps = int(0.1 * total_train_steps)

# Create a learning rate scheduler
lr_scheduler = get_linear_schedule_with_warmup(
    optimizer,
    num_warmup_steps=num_warmup_steps,
    num_training_steps=total_train_steps,
)

# Define the output directory for saving the model
saved_dir = '/content/drive/MyDrive/intent_classification_It_bombay/trained_model_10_checkpoints/'

# Training loop with tqdm progress bar
"looping over epochs and fold"
for epoch in range(num_epochs_per_fold):
  for k in range(5):
    train_data_loader=train_dataloader_kfold[k]
    for i, batch in enumerate(train_data_loader):
      model.train()
      total_loss=0.0
      # progress_bar=tqdm(enumerate(train_data), total=len(train_data), desc=f"Epoch {epoch} - Fold {fold_idx}")
      # for step, batch in progress_bar:
        # move data to GPU
      batch={k:v.to(device) for k, v in batch.items()}

      # forward pass
      outputs=model(**batch)
      loss=outputs.loss

      # backward pass and optimization
      loss.backward()
      optimizer.step()
      optimizer.zero_grad()

      # update the learning rate
      lr_scheduler.step()

      # calculate the total loss
      total_loss+=loss.item()
      if i%20==0:
        print(f"training loss at epoch {epoch} batch {i}, fold{k} is : {total_loss}")
    print(f"at the end training loss at epoch {epoch} batch {i}, fold{k} is : {total_loss}")



  # Save the model checkpoint at the end of each epoch
    checkpoint_dir = os.path.join(saved_dir, f"epoch_{epoch}_fold_{k}")
    os.makedirs(checkpoint_dir, exist_ok=True)

    # Save model weights
    model.save_pretrained(checkpoint_dir)

    # Save optimizer state
    # torch.save(optimizer.state_dict(), os.path.join(checkpoint_dir, "optimizer.pt"))

    # Save learning rate scheduler state
    # torch.save(lr_scheduler.state_dict(), os.path.join(checkpoint_dir, "scheduler.pt"))

    # Save RNG state (if needed)
    torch.save(torch.get_rng_state(), os.path.join(checkpoint_dir, "rng_state.pth"))

    # Save config.json (if needed)
    model.config.save_pretrained(checkpoint_dir)

    # Save tokenizer (if needed)
    tokenizer.save_pretrained(checkpoint_dir)

      # # Save the model checkpoint every epoch or after a specific number of steps
      # if epoch % training_args.save_steps == 0:
      #     checkpoint_dir = os.path.join(saved_dir, f"epoch_{epoch}")
      #     os.makedirs(checkpoint_dir, exist_ok=True)
      #     model.save_pretrained(checkpoint_dir)

    test_data_loader=test_dataloader_kfold[k]
    for i, batch in enumerate(test_data_loader):
      model.eval()
      eval_loss=0.0
      # progress_bar_eval=tqdm(enumerate(test_data), total=len(test_data),desc=f"Epoch {epoch} - Fold {fold_idx}")
      # for step, batch in progress_bar_eval:
      batch={k:v.to(device) for k,v in batch.items()}
      with torch.no_grad():
        outputs=model(**batch)
        loss=outputs.loss
        eval_loss+=loss.item()
      if i%2==0:
        print(f"evaluation loss at epoch {epoch} batch {i}, fold{k} is : {eval_loss}")
    print(f" At the end evaluation loss at epoch {epoch} batch {i}, fold{k} is : {eval_loss}")
