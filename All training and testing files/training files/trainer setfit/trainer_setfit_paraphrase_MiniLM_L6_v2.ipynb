# %% [markdown]
# # **Connecting google colab to drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **Installing the dependencies**

# %%
# !pip install transformers
# Out:
# Collecting transformers
#   Downloading transformers-4.34.0-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 55.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.4)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 34.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 104.0 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 83.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Installing collected packages: safetensors, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.17.3 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.34.0

# %%
# !pip install -U sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.34.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.15.2+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (3.8.1)
# Collecting sentencepiece (from sentence-transformers)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 42.1 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.17.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.12.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (17.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2023.6.3)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=685c25d4bb9622f719fc03660ddb0bfc0d07a3efafc37b7afe395b4ecb068e54
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: sentencepiece, sentence-transformers
# Successfully installed sentence-transformers-2.2.2 sentencepiece-0.1.99

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.14.5-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 20.4 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.9 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<2023.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.17.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (3.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (3.12.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-2.14.5 dill-0.3.7 multiprocess-0.70.15 xxhash-3.4.1

# %%
# !pip install setfit
# Out:
# Collecting setfit
#   Downloading setfit-0.7.0-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 984.7 kB/s eta 0:00:00
# Requirement already satisfied: datasets>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from setfit) (2.14.5)
# Requirement already satisfied: sentence-transformers>=2.2.1 in /usr/local/lib/python3.10/dist-packages (from setfit) (2.2.2)
# Collecting evaluate>=0.3.0 (from setfit)
#   Downloading evaluate-0.4.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (9.0.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (0.70.15)
# Requirement already satisfied: fsspec[http]<2023.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (3.8.5)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (0.17.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.3.0->setfit) (6.0.1)
# Collecting responses<0.19 (from evaluate>=0.3.0->setfit)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (4.34.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (0.15.2+cu118)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (1.11.3)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.1->setfit) (0.1.99)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (3.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.3.0->setfit) (1.3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets>=2.3.0->setfit) (3.12.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets>=2.3.0->setfit) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.3.0->setfit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.3.0->setfit) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets>=2.3.0->setfit) (2023.7.22)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (17.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.1->setfit) (2023.6.3)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.1->setfit) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.1->setfit) (0.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=2.2.1->setfit) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=2.2.1->setfit) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.3.0->setfit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.3.0->setfit) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers>=2.2.1->setfit) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=2.2.1->setfit) (9.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets>=2.3.0->setfit) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=2.2.1->setfit) (1.3.0)
# Installing collected packages: responses, evaluate, setfit
# Successfully installed evaluate-0.4.0 responses-0.18.0 setfit-0.7.0

# %% [markdown]
# # **Loading the surprise data and its showing and converting them into Json format**

# %%
import json
import pandas as pd
data_path="/content/drive/MyDrive/intent_classification_It_bombay/indoml_iit_bombay/surprise_data/surprise.data"
data_label_path="/content/drive/MyDrive/intent_classification_It_bombay/indoml_iit_bombay/surprise_data/surprise.solution"
with open(data_path,'r') as file:
	files=file.readlines()
# print(files)
# print(len(files))
print('\n')
# print(files[0])
files_list=[]
for line in files:
	line=line.strip('\n')
	line=json.loads(line)
	files_list.append(line)
# print(dict)
print(len(files_list))
# for element in dict:
	# print(element)
	# print('\n')
# Out:
# 2248

# %%
# files

# %%
with open(data_label_path,'r') as file:
	labels=file.readlines()
print(labels)
label_list=[]
for label in labels:
  label.strip('\n')
  label=json.loads(label)
  label_list.append(label)
print(label_list)
# Out:
# ['{"indoml_id": "surprise|11109", "intent": "accept reservations"}\n', '{"indoml_id": "surprise|11051", "intent": "accept reservations"}\n', '{"indoml_id": "surprise|11021", "intent": "accept reservations"}\n', '{"indoml_id": "surprise|11047", "intent": "accept reservations"}\n', '{"indoml_id": "surprise|11004", "intent": "accept reservations"}\n', '{"indoml_id": "surprise|11097", "intent": "accept reservations"}\n', '{"indoml_id": "surprise|10998", "intent": "accept reservations"}\n', '{"indoml_id": "surprise|11050", "intent": "accept reservations"}\n', '{"indoml_id": "surprise|11035", "intent": "accept reservations"}\n', '{"indoml_id": "surprise|11030", "intent": "accept reservations"}\n', '{"indoml_id": "surprise|11127", "intent": "accept reservations"}\n', '{"indoml_id": "surprise|11042", "intent": "accept reservations"}\n', '{"indoml_id": "surprise|11105", "intent": "accept reservations"}\n', '{"indoml_id": "surprise|11139", "intent": "accept reservations"}\n', '{"indoml_id": "surprise|11039", "intent": "accept reservations"}\n', '{"indoml_id": "surprise|11590", "intent": "account blocked"}\n', '{"indoml_id": "surprise|11604", "intent": "account blocked"}\n', '{"indoml_id": "surprise|11574", "intent": "account blocked"}\n', '{"indoml_id": "surprise|11631", "intent": "account blocked"}\n', '{"indoml_id": "surprise|11625", "intent": "account blocked"}\n', '{"indoml_id": "surprise|11637", "intent": "account blocked"}\n', '{"indoml_id": "surprise|11561", "intent": "account blocked"}\n', '{"indoml_id": "surprise|11599", "intent": "account blocked"}\n', '{"indoml_id": "surprise|11621", "intent": "account blocked"}\n', '{"indoml_id": "surprise|11546", "intent": "account blocked"}\n', '{"indoml_id": "surprise|11596", "intent": "account blocked"}\n', '{"indoml_id": "surprise|11557", "intent": "account blocked"}\n', '{"indoml_id": "surprise|11603", "intent": "account blocked"}\n', '{"indoml_id": "surprise|11591", "intent": "account blocked"}\n', '{"indoml_id": "surprise|11579", "intent": "account blocked"}\n', '{"indoml_id": "surprise|8843", "intent": "alarm"}\n', '{"indoml_id": "surprise|8759", "intent": "alarm"}\n', '{"indoml_id": "surprise|8744", "intent": "alarm"}\n', '{"indoml_id": "surprise|8709", "intent": "alarm"}\n', '{"indoml_id": "surprise|8824", "intent": "alarm"}\n', '{"indoml_id": "surprise|8788", "intent": "alarm"}\n', '{"indoml_id": "surprise|8701", "intent": "alarm"}\n', '{"indoml_id": "surprise|8783", "intent": "alarm"}\n', '{"indoml_id": "surprise|8797", "intent": "alarm"}\n', '{"indoml_id": "surprise|8847", "intent": "alarm"}\n', '{"indoml_id": "surprise|8813", "intent": "alarm"}\n', '{"indoml_id": "surprise|8752", "intent": "alarm"}\n', '{"indoml_id": "surprise|8768", "intent": "alarm"}\n', '{"indoml_id": "surprise|8742", "intent": "alarm"}\n', '{"indoml_id": "surprise|8757", "intent": "alarm"}\n', '{"indoml_id": "surprise|1837", "intent": "application status"}\n', '{"indoml_id": "surprise|1809", "intent": "application status"}\n', '{"indoml_id": "surprise|1821", "intent": "application status"}\n', '{"indoml_id": "surprise|1802", "intent": "application status"}\n', '{"indoml_id": "surprise|1815", "intent": "application status"}\n', '{"indoml_id": "surprise|1827", "intent": "application status"}\n', '{"indoml_id": "surprise|1807", "intent": "application status"}\n', '{"indoml_id": "surprise|1804", "intent": "application status"}\n', '{"indoml_id": "surprise|1838", "intent": "application status"}\n', '{"indoml_id": "surprise|1805", "intent": "application status"}\n', '{"indoml_id": "surprise|1819", "intent": "application status"}\n', '{"indoml_id": "surprise|1811", "intent": "application status"}\n', '{"indoml_id": "surprise|1808", "intent": "application status"}\n', '{"indoml_id": "surprise|1812", "intent": "application status"}\n', '{"indoml_id": "surprise|1825", "intent": "application status"}\n', '{"indoml_id": "surprise|6402", "intent": "apr"}\n', '{"indoml_id": "surprise|6369", "intent": "apr"}\n', '{"indom ...
# [{'indoml_id': 'surprise|11109', 'intent': 'accept reservations'}, {'indoml_id': 'surprise|11051', 'intent': 'accept reservations'}, {'indoml_id': 'surprise|11021', 'intent': 'accept reservations'}, {'indoml_id': 'surprise|11047', 'intent': 'accept reservations'}, {'indoml_id': 'surprise|11004', 'intent': 'accept reservations'}, {'indoml_id': 'surprise|11097', 'intent': 'accept reservations'}, {'indoml_id': 'surprise|10998', 'intent': 'accept reservations'}, {'indoml_id': 'surprise|11050', 'intent': 'accept reservations'}, {'indoml_id': 'surprise|11035', 'intent': 'accept reservations'}, {'indoml_id': 'surprise|11030', 'intent': 'accept reservations'}, {'indoml_id': 'surprise|11127', 'intent': 'accept reservations'}, {'indoml_id': 'surprise|11042', 'intent': 'accept reservations'}, {'indoml_id': 'surprise|11105', 'intent': 'accept reservations'}, {'indoml_id': 'surprise|11139', 'intent': 'accept reservations'}, {'indoml_id': 'surprise|11039', 'intent': 'accept reservations'}, {'indoml_id': 'surprise|11590', 'intent': 'account blocked'}, {'indoml_id': 'surprise|11604', 'intent': 'account blocked'}, {'indoml_id': 'surprise|11574', 'intent': 'account blocked'}, {'indoml_id': 'surprise|11631', 'intent': 'account blocked'}, {'indoml_id': 'surprise|11625', 'intent': 'account blocked'}, {'indoml_id': 'surprise|11637', 'intent': 'account blocked'}, {'indoml_id': 'surprise|11561', 'intent': 'account blocked'}, {'indoml_id': 'surprise|11599', 'intent': 'account blocked'}, {'indoml_id': 'surprise|11621', 'intent': 'account blocked'}, {'indoml_id': 'surprise|11546', 'intent': 'account blocked'}, {'indoml_id': 'surprise|11596', 'intent': 'account blocked'}, {'indoml_id': 'surprise|11557', 'intent': 'account blocked'}, {'indoml_id': 'surprise|11603', 'intent': 'account blocked'}, {'indoml_id': 'surprise|11591', 'intent': 'account blocked'}, {'indoml_id': 'surprise|11579', 'intent': 'account blocked'}, {'indoml_id': 'surprise|8843', 'intent': 'alarm'}, {'indoml_id': 'surprise|8759', 'intent': 'alarm'}, {'indoml_id': 'surprise|8744', 'intent': 'alarm'}, {'indoml_id': 'surprise|8709', 'intent': 'alarm'}, {'indoml_id': 'surprise|8824', 'intent': 'alarm'}, {'indoml_id': 'surprise|8788', 'intent': 'alarm'}, {'indoml_id': 'surprise|8701', 'intent': 'alarm'}, {'indoml_id': 'surprise|8783', 'intent': 'alarm'}, {'indoml_id': 'surprise|8797', 'intent': 'alarm'}, {'indoml_id': 'surprise|8847', 'intent': 'alarm'}, {'indoml_id': 'surprise|8813', 'intent': 'alarm'}, {'indoml_id': 'surprise|8752', 'intent': 'alarm'}, {'indoml_id': 'surprise|8768', 'intent': 'alarm'}, {'indoml_id': 'surprise|8742', 'intent': 'alarm'}, {'indoml_id': 'surprise|8757', 'intent': 'alarm'}, {'indoml_id': 'surprise|1837', 'intent': 'application status'}, {'indoml_id': 'surprise|1809', 'intent': 'application status'}, {'indoml_id': 'surprise|1821', 'intent': 'application status'}, {'indoml_id': 'surprise|1802', 'intent': 'application status'}, {'indoml_id': 'surprise|1815', 'intent': 'application status'}, {'indoml_id': 'surprise|1827', 'intent': 'application status'}, {'indoml_id': 'surprise|1807', 'intent': 'application status'}, {'indoml_id': 'surprise|1804', 'intent': 'application status'}, {'indoml_id': 'surprise|1838', 'intent': 'application status'}, {'indoml_id': 'surprise|1805', 'intent': 'application status'}, {'indoml_id': 'surprise|1819', 'intent': 'application status'}, {'indoml_id': 'surprise|1811', 'intent': 'application status'}, {'indoml_id': 'surprise|1808', 'intent': 'application status'}, {'indoml_id': 'surprise|1812', 'intent': 'application status'}, {'indoml_id': 'surprise|1825', 'intent': 'application status'}, {'indoml_id': 'surprise|6402', 'intent': 'apr'}, {'indoml_id': 'surprise|6369', 'intent': 'apr'}, {'indoml_id': 'surprise|6364', 'intent': 'apr'}, {'indoml_id': 'surprise|6405', 'intent': 'apr'}, {'indoml_id': 'surprise|6351', 'intent': 'apr'}, {'indoml_id': 'surprise|6410', 'intent': 'apr'}, {'indoml_id': 'surprise|6374', 'intent': 'apr'}, {'indoml_id ...

# %%
from transformers import AutoTokenizer
"loading the pretratined model from the hugging face by IBM trained on another intent classification task on 180 labels"
model_name="ibm/roberta-large-vira-intents" # by the IBM on 180 labels

tokenizer=AutoTokenizer.from_pretrained(model_name)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/351 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]

# %% [markdown]
# # **Converting the files list from above (contain utterances for the surprise dataset) and label list(containing intent for those utterances) into the dictionary having keys as indoml id, utt and indoml id and intent**

# %%
import pandas as pd
indoml_id_file=[]
utt=[]
indoml_id_label=[]
intent=[]


files_dict={}
label_dict={}
for file in files_list:
  indoml_id_file.append(file['indoml_id'])
  utt.append(file['utt'])
  files_dict['indoml_id']=indoml_id_file
  files_dict['utt']=utt

for file in label_list:
  indoml_id_label.append(file['indoml_id'])
  intent.append(file['intent'])
  label_dict['indoml_id']=indoml_id_label
  label_dict['intent']=intent

# %% [markdown]
# # **Converting files_dict and labels_dict obtained from above into  into pandas dataframe**

# %%
files_pd=pd.DataFrame.from_dict(files_dict)
files_pd
# Out:
#            indoml_id                                                utt
# 0     surprise|11109    Can I make a reservation at Buffalo Wild Wings?
# 1     surprise|11051      Can I book a table for tonight at Bella Vita?
# 2     surprise|11021     Does the Cheesecake Factory take reservations?
# 3     surprise|11047  Do they take reservations at Outback Steakhous...
# 4     surprise|11004                    does chili's take reservations?
# ...              ...                                                ...
# 2243   surprise|5290                    indeed, that's what I was told!
# 2244   surprise|5254        Oh, without a doubt, that's absolutely true
# 2245   surprise|5246                 Absolutely, I couldn't agree more!
# 2246   surprise|5401                           It's a wonderful notion!
# 2247   surprise|5403                          That's a superb solution!
#
# [2248 rows x 2 columns]

# %%
labels_pd=pd.DataFrame.from_dict(label_dict)
labels_pd
# Out:
#            indoml_id               intent
# 0     surprise|11109  accept reservations
# 1     surprise|11051  accept reservations
# 2     surprise|11021  accept reservations
# 3     surprise|11047  accept reservations
# 4     surprise|11004  accept reservations
# ...              ...                  ...
# 2243   surprise|5290                  yes
# 2244   surprise|5254                  yes
# 2245   surprise|5246                  yes
# 2246   surprise|5401                  yes
# 2247   surprise|5403                  yes
#
# [2248 rows x 2 columns]

# %%
labels_pd['intent'].unique() # we have here a total of 150 unique intents
# Out:
# array(['accept reservations', 'account blocked', 'alarm',
#        'application status', 'apr', 'are you a bot', 'balance',
#        'bill balance', 'bill due', 'book flight', 'book hotel',
#        'calculator', 'calendar', 'calendar update', 'calories', 'cancel',
#        'cancel reservation', 'car rental', 'card declined', 'carry on',
#        'change accent', 'change ai name', 'change language',
#        'change speed', 'change user name', 'change volume',
#        'confirm reservation', 'cook time', 'credit limit',
#        'credit limit change', 'credit score', 'current location',
#        'damaged card', 'date', 'definition', 'direct deposit',
#        'directions', 'distance', 'do you have pets', 'exchange rate',
#        'expiration date', 'find phone', 'flight status', 'flip coin',
#        'food last', 'freeze account', 'fun fact', 'gas', 'gas type',
#        'goodbye', 'greeting', 'how busy', 'how old are you',
#        'improve credit score', 'income', 'ingredient substitution',
#        'ingredients list', 'insurance', 'insurance change',
#        'interest rate', 'international fees', 'international visa',
#        'jump start', 'last maintenance', 'lost luggage', 'make call',
#        'maybe', 'meal suggestion', 'meaning of life',
#        'measurement conversion', 'meeting schedule', 'min payment', 'mpg',
#        'new card', 'next holiday', 'next song', 'no', 'nutrition info',
#        'oil change how', 'oil change when', 'order', 'order checks',
#        'order status', 'pay bill', 'payday', 'pin change', 'play music',
#        'plug type', 'pto balance', 'pto request', 'pto request status',
#        'pto used', 'recipe', 'redeem rewards', 'reminder',
#        'reminder update', 'repeat', 'replacement card duration',
#        'report fraud', 'report lost card', 'reset settings',
#        'restaurant reservation', 'restaurant reviews',
#        'restaurant suggestion', 'rewards balance', 'roll dice',
#        'rollover 401k', 'routing', 'schedule maintenance',
#        'schedule meeting', 'share location', 'shopping list',
#        'shopping list update', 'smart home', 'spelling',
#        'spending history', 'sync device', 'taxes', 'tell joke', 'text',
#        'thank you', 'time', 'timer', 'timezone', 'tire change',
#        'tire pressure', 'todo list', 'todo list update', 'traffic',
#        'transactions', 'transfer', 'translate', 'travel alert',
#        'travel notification', 'travel suggestion', 'uber',
#        'update playlist', 'user name', 'vaccines', 'w2', 'weather',
#        'what are your hobbies', 'what can i ask you', 'what is your name',
#        'what song', 'where are you from', 'whisper mode',
#        'who do you work for', 'who made you', 'yes'], dtype=object)

# %% [markdown]
# # **merging both dataframe obtained above on the basis of common indoml id**

# %%
Data_pd=pd.merge(files_pd, labels_pd, on='indoml_id', how='inner')
Data_pd
# Out:
#            indoml_id                                                utt  \
# 0     surprise|11109    Can I make a reservation at Buffalo Wild Wings?
# 1     surprise|11051      Can I book a table for tonight at Bella Vita?
# 2     surprise|11021     Does the Cheesecake Factory take reservations?
# 3     surprise|11047  Do they take reservations at Outback Steakhous...
# 4     surprise|11004                    does chili's take reservations?
# ...              ...                                                ...
# 2243   surprise|5290                    indeed, that's what I was told!
# 2244   surprise|5254        Oh, without a doubt, that's absolutely true
# 2245   surprise|5246                 Absolutely, I couldn't agree more!
# 2246   surprise|5401                           It's a wonderful notion!
# 2247   surprise|5403                          That's a superb solution!
#
#                    intent
# 0     accept reservations
# 1     accept reservations
# 2     accept reservations
# 3     accept reservations
# 4     accept reservations
# ...                   ...
# 2243                  yes
# 2244                  yes
# 2245                  yes
# 2246                  yes
# 2247                  yes
#
# [2248 rows x 3 columns]

# %%
Data_pd.drop('indoml_id', axis=1, inplace=True)

# %%
Data_pd
# Out:
#                                                     utt               intent
# 0       Can I make a reservation at Buffalo Wild Wings?  accept reservations
# 1         Can I book a table for tonight at Bella Vita?  accept reservations
# 2        Does the Cheesecake Factory take reservations?  accept reservations
# 3     Do they take reservations at Outback Steakhous...  accept reservations
# 4                       does chili's take reservations?  accept reservations
# ...                                                 ...                  ...
# 2243                    indeed, that's what I was told!                  yes
# 2244        Oh, without a doubt, that's absolutely true                  yes
# 2245                 Absolutely, I couldn't agree more!                  yes
# 2246                           It's a wonderful notion!                  yes
# 2247                          That's a superb solution!                  yes
#
# [2248 rows x 2 columns]

# %% [markdown]
# # **Encoding all the labels into integar format to be able to use them further**

# %%
labels_intent_list=[]
for label in label_list:
      labels_intent_list.append(label['intent'])
unique_labels_list=[]
for x in labels_intent_list:
    if x not in unique_labels_list:
        unique_labels_list.append(x)
# unique_labels_list, len(unique_labels_list)

label2id={}
id2label={}
for i, label in enumerate(unique_labels_list):
    label2id[label]=i
    id2label[i]=label
# converting the intent into id by label2id
labels=[label2id[intent] for intent in Data_pd['intent']]
labels[10], len(labels)
# Out:
# array([  0,   0,   0, ..., 149, 149, 149])

# %%
Data_pd['labels']=labels
Data_pd
# Out:
#                                                     utt               intent  \
# 0       Can I make a reservation at Buffalo Wild Wings?  accept reservations
# 1         Can I book a table for tonight at Bella Vita?  accept reservations
# 2        Does the Cheesecake Factory take reservations?  accept reservations
# 3     Do they take reservations at Outback Steakhous...  accept reservations
# 4                       does chili's take reservations?  accept reservations
# ...                                                 ...                  ...
# 2243                    indeed, that's what I was told!                  yes
# 2244        Oh, without a doubt, that's absolutely true                  yes
# 2245                 Absolutely, I couldn't agree more!                  yes
# 2246                           It's a wonderful notion!                  yes
# 2247                          That's a superb solution!                  yes
#
#       labels
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 2243     149
# 2244     149
# 2245     149
# 2246     149
# 2247     149
#
# [2248 rows x 3 columns]

# %%
# Data_pd['intent'].unique()

# %% [markdown]
# # **renaming utt as text and intent as label text as per the requirements of setfit**

# %%
Data_pd.rename(columns={'utt':'text','intent':'label_text'}, inplace=True)
Data_pd
# Out:
#                                                    text           label_text  \
# 0       Can I make a reservation at Buffalo Wild Wings?  accept reservations
# 1         Can I book a table for tonight at Bella Vita?  accept reservations
# 2        Does the Cheesecake Factory take reservations?  accept reservations
# 3     Do they take reservations at Outback Steakhous...  accept reservations
# 4                       does chili's take reservations?  accept reservations
# ...                                                 ...                  ...
# 2243                    indeed, that's what I was told!                  yes
# 2244        Oh, without a doubt, that's absolutely true                  yes
# 2245                 Absolutely, I couldn't agree more!                  yes
# 2246                           It's a wonderful notion!                  yes
# 2247                          That's a superb solution!                  yes
#
#       labels
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 2243     149
# 2244     149
# 2245     149
# 2246     149
# 2247     149
#
# [2248 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
train_ds, test_ds=train_test_split(Data_pd, test_size=0.1, random_state=32) # splitting total data into 90% for the training and 10% for the testing

# %%
train_ds
# Out:
#                                                    text          label_text  \
# 1398  Can I trade my American Express points for cas...      redeem rewards
# 1962      send $50 from joint account to single account            transfer
# 1810                Your generosity is truly inspiring!           thank you
# 1752                Kindly link my smartphone to Wi-Fi.         sync device
# 232    Cancel our reservation at the restaurant tonight              cancel
# ...                                                 ...                 ...
# 510                    explain the definition of bubbly          definition
# 252   I would like to cancel my table for 8pm at Bis...  cancel reservation
# 2136            what is the scope of your capabilities?  what can i ask you
# 1334  How many hours of PTO do I have left before th...         pto balance
# 1579  Roll a 10-sided die and tell me if it lands on...           roll dice
#
#       labels
# 1398      93
# 1962     130
# 1810     120
# 1752     116
# 232       15
# ...      ...
# 510       34
# 252       16
# 2136     142
# 1334      88
# 1579     105
#
# [2023 rows x 3 columns]

# %%
len(train_ds['label_text'].unique()),train_ds['label_text'].unique()
# Out:
# (150,
#  array(['redeem rewards', 'transfer', 'thank you', 'sync device', 'cancel',
#         'payday', 'what can i ask you', 'calculator', 'oil change how',
#         'make call', 'pto balance', 'freeze account',
#         'what are your hobbies', 'meeting schedule', 'date', 'apr',
#         'calories', 'pto request', 'insurance change', 'fun fact',
#         'how old are you', 'pto request status', 'are you a bot',
#         'book hotel', 'weather', 'yes', 'ingredients list',
#         'accept reservations', 'plug type', 'ingredient substitution',
#         'current location', 'gas type', 'calendar', 'insurance',
#         'smart home', 'damaged card', 'what song', 'change language',
#         'report lost card', 'mpg', 'traffic', 'carry on', 'directions',
#         'credit score', 'direct deposit', 'card declined', 'transactions',
#         'uber', 'lost luggage', 'reminder', 'restaurant reviews',
#         'rollover 401k', 'no', 'how busy', 'order status', 'interest rate',
#         'min payment', 'calendar update', 'pin change', 'distance',
#         'report fraud', 'translate', 'greeting', 'w2', 'pto used',
#         'bill balance', 'repeat', 'schedule meeting', 'update playlist',
#         'user name', 'travel suggestion', 'meaning of life', 'timezone',
#         'play music', 'change accent', 'replacement card duration',
#         'do you have pets', 'definition', 'meal suggestion',
#         'international visa', 'shopping list update', 'next song',
#         'nutrition info', 'confirm reservation', 'expiration date',
#         'credit limit change', 'next holiday', 'tire pressure',
#         'tell joke', 'text', 'order', 'what is your name',
#         'who do you work for', 'todo list', 'reset settings', 'goodbye',
#         'taxes', 'shopping list', 'new card', 'routing', 'share location',
#         'book flight', 'schedule maintenance', 'measurement conversion',
#         'account blocked', 'whisper mode', 'income', 'roll dice',
#         'change volume', 'alarm', 'jump start', 'recipe',
#         'change user name', 'bill due', 'find phone',
#         'improve credit score', 'international fees', 'pay bill',
#         'vaccines', 'travel notification', 'application status',
#         'reminder update', 'change ai name', 'cancel reservation',
#         'flight status', 'cook time', 'oil change when',
#         'last maintenance', 'tire change', 'restaurant reservation',
#         'credit limit', 'flip coin', 'spending history', 'time',
#         'food last', 'who made you', 'rewards balance',
#         'where are you from', 'travel alert', 'maybe', 'timer',
#         'exchange rate', 'order checks', 'balance',
#         'restaurant suggestion', 'change speed', 'gas', 'car rental',
#         'todo list update', 'spelling'], dtype=object))

# %%
len(test_ds['label_text'].unique()),test_ds['label_text'].unique()
# Out:
# (122,
#  array(['order status', 'cancel', 'application status',
#         'restaurant reviews', 'reminder update', 'confirm reservation',
#         'credit limit', 'tire pressure', 'travel notification', 'vaccines',
#         'last maintenance', 'pto used', 'spending history', 'cook time',
#         'book flight', 'who made you', 'find phone', 'rollover 401k',
#         'pay bill', 'shopping list update', 'todo list', 'travel alert',
#         'greeting', 'timer', 'routing', 'min payment', 'gas', 'distance',
#         'direct deposit', 'restaurant suggestion', 'mpg', 'share location',
#         'international visa', 'ingredient substitution', 'oil change how',
#         'nutrition info', 'recipe', 'play music', 'text', 'book hotel',
#         'credit limit change', 'spelling', 'lost luggage',
#         'rewards balance', 'goodbye', 'damaged card', 'user name',
#         'pto request status', 'meeting schedule', 'smart home', 'payday',
#         'translate', 'new card', 'interest rate', 'credit score',
#         'directions', 'order', 'income', 'transfer', 'balance',
#         'freeze account', 'measurement conversion', 'schedule maintenance',
#         'calendar', 'report lost card', 'ingredients list', 'taxes',
#         'pto balance', 'timezone', 'time', 'what can i ask you',
#         'next holiday', 'current location', 'redeem rewards',
#         'exchange rate', 'tire change', 'date', 'bill due',
#         'do you have pets', 'change ai name', 'order checks',
#         'travel suggestion', 'sync device', 'bill balance',
#         'insurance change', 'transactions', 'calculator', 'uber', 'no',
#         'traffic', 'reminder', 'roll dice', 'maybe', 'what is your name',
#         'food last', 'fun fact', 'card declined', 'repeat', 'gas type',
#         'thank you', 'improve credit score', 'pin change', 'next song',
#         'plug type', 'flight status', 'update playlist', 'jump start',
#         'definition', 'change volume', 'who do you work for',
#         'calendar update', 'are you a bot', 'reset settings',
#         'account blocked', 'car rental', 'international fees',
#         'todo list update', 'change speed', 'schedule meeting', 'carry on',
#         'yes', 'insurance'], dtype=object))

# %%
len(train_ds), len(test_ds)
# Out:
# (2023, 225)

# %%
train_ds.drop('label_text', axis=1, inplace=True)
test_ds.drop('label_text', axis=1, inplace=True)

# %%
train_ds.to_csv('train.csv',index=False)
test_ds.to_csv('test.csv', index=False)

# %%
# intent_count=Data_pd['intent'].unique()
# print(len(intent_count))

# %%
# for int in intent_count:
#   print(int)

# %%
# for utt in Data_pd['utt']:
#   print(utt)

# %%
train_ds, test_ds
# Out:
# (                                                   text  labels
#  1398  Can I trade my American Express points for cas...      93
#  1962      send $50 from joint account to single account     130
#  1810                Your generosity is truly inspiring!     120
#  1752                Kindly link my smartphone to Wi-Fi.     116
#  232    Cancel our reservation at the restaurant tonight      15
#  ...                                                 ...     ...
#  510                    explain the definition of bubbly      34
#  252   I would like to cancel my table for 8pm at Bis...      16
#  2136            what is the scope of your capabilities?     142
#  1334  How many hours of PTO do I have left before th...      88
#  1579  Roll a 10-sided die and tell me if it lands on...     105
#
#  [2023 rows x 2 columns],
#                                                     text  labels
#  1243  I would appreciate it if you could give me a p...      82
#  233    Cancel the event that was scheduled for tomorrow      15
#  56    I'm eagerly waiting to find out if my loan app...       3
#  1535  what are the opinions on the service at Olive ...     102
#  1427       Make a note to call my sister back tomorrow.      95
#  ...                                                 ...     ...
#  1838                        Set a timer for 20 minutes.     122
#  2244        Oh, without a doubt, that's absolutely true     149
#  1652         share my location information with rachel.     110
#  862                  How does my health insurance work?      57
#  660              how long does milk last in the fridge?      44
#
#  [225 rows x 2 columns])

# %%
from datasets import load_dataset
from sentence_transformers.losses import CosineSimilarityLoss
from setfit import SetFitModel, SetFitTrainer

# %%
train_dataset=load_dataset('csv', data_files='/content/train.csv')
# Out:
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
test_dataset=load_dataset('csv', data_files='/content/test.csv')
# Out:
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
train_dataset['train'], test_dataset['train']
# Out:
# (Dataset({
#      features: ['text', 'labels'],
#      num_rows: 2023
#  }),
#  Dataset({
#      features: ['text', 'labels'],
#      num_rows: 225
#  }))

# %%
model_id='sentence-transformers/paraphrase-MiniLM-L6-v2'
"""paraphrase-MiniLM-L6-v2' model is designed for paraphrase identification, which means it's trained to determine whether two sentences or phrases have the same or similar meaning.
It's particularly useful for tasks like text similarity, semantic matching, and paraphrase detection"""
model=SetFitModel.from_pretrained(model_id)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/8.66k [00:00<?, ?B/s]
# Downloading (…)36ffa/.gitattributes:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# Downloading (…)579f63c36ffa/LICENSE:   0%|          | 0.00/11.4k [00:00<?, ?B/s]
# Downloading (…)9f63c36ffa/README.md:   0%|          | 0.00/1.70k [00:00<?, ?B/s]
# Downloading (…)63c36ffa/config.json:   0%|          | 0.00/8.66k [00:00<?, ?B/s]
# Downloading (…)f63c36ffa/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading (…)36ffa/tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/351 [00:00<?, ?B/s]
# Downloading (…)f63c36ffa/vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# WARNING:sentence_transformers.SentenceTransformer:No sentence-transformers model found with name /root/.cache/torch/sentence_transformers/ibm_roberta-large-vira-intents. Creating a new one with MEAN pooling.
# Some weights of RobertaModel were not initialized from the model checkpoint at /root/.cache/torch/sentence_transformers/ibm_roberta-large-vira-intents and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# model_head.pkl not found on HuggingFace Hub, initialising classification head with random weights. You should TRAIN this model on a downstream task to use it for predictions and inference.

# %%
trainer=SetFitTrainer(
    model=model,
    train_dataset=train_dataset['train'],
    eval_dataset=test_dataset['train'],
    loss_class=CosineSimilarityLoss,
    metric='accuracy',
    batch_size=32,
    num_iterations=20,  # Find the closest 5 stories of the corpus for each query sentence based on cosine similarity
    num_epochs=5,
    column_mapping={'text':'text','labels':'label'}

)

# %%
trainer.train()

# %%
metrics=trainer.evaluate()
metrics

# %% [markdown]
# # **loading the testing data**

# %%
test_data_path="/content/drive/MyDrive/intent_classification_It_bombay/massive_test_phase2_data/massive_test.data"
with open(test_data_path,'r') as test_file:
        test_data=[json.loads(line) for line in test_file] # reading json data from data_path and parse it into a test_data list
test_text = [item["utt"] for item in test_data] # extracting utt(test_text) from the testing data

# %%
prediction=model.predict(test_text)

# %%
predicted_labels=[id2label[int(id)] for id in list(prediction)]
# Out:
# array(['transactions', 'order', 'sync device', ..., 'account blocked',
#        'meal suggestion', 'cancel'], dtype=object)

# %%
preds=model(["How long will my account remain inaccessible before it's unblocked?","Absolutelbsolutely! I couldn't agree more!y! I couldn't agree more!"])
preds
# Out:
# tensor([  1, 149])

# %%
# import pandas as pd
# my_id=[]
# my_intent1=[]

# my_dict1={}
# for i, entry in enumerate(solution_list):
#     my_id.append({'indoml_id':i+1,'intent':predicted_labels[i]})
#     my_intent1.append(predicted_labels[i])
#     my_dict1['id']=my_id
#     my_dict1['intent1']=my_intent1
# #     temp={}
# #     temp['indoml_id']=entry['locale']+'/'+entry['id']
# #     temp['intent']=entry['pred_intent']
# #     my_dict['k']=temp
# #     k+=1
# my_dict1_pd=pd.DataFrame.from_dict(my_dict1)
# my_dict1_pd.head()

# %%
# with open('output.predict', 'w') as out_file:
#     for entry in my_dict1_pd['id']:
#         out_file.write(str(entry))
#         out_file.write('\n')
