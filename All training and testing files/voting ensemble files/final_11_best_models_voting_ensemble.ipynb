# %% [markdown]
# # **got 91.06% result using this file and here we have joined total 11 model which are given below**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
massive_1_path="/content/drive/MyDrive/massive_accuracy_files_in_descending_order/massive_test_0.8936.predict"
massive_2_path="/content/drive/MyDrive/massive_accuracy_files_in_descending_order/massive_test_.8925.predict"
massive_3_path="/content/drive/MyDrive/massive_accuracy_files_in_descending_order/massive_0.892.predict"
massive_4_path="/content/drive/MyDrive/massive_accuracy_files_in_descending_order/massive_test_.8918.predict"
massive_5_path="/content/drive/MyDrive/massive_accuracy_files_in_descending_order/massive_test_.89.predict"
massive_6_path="/content/drive/MyDrive/massive_accuracy_files_in_descending_order/massive_2.predict"
massive_7_path="/content/drive/MyDrive/massive_accuracy_files_in_descending_order/massive_4.predict"
massive_8_path="/content/drive/MyDrive/massive_accuracy_files_in_descending_order/massive_0.8847.predict"
massive_9_path="/content/drive/MyDrive/massive_accuracy_files_in_descending_order/massive_0.8841.predict"
massive_10_path="/content/drive/MyDrive/massive_accuracy_files_in_descending_order/massive_0.8913.predict"
massive_11_path="/content/drive/MyDrive/massive_accuracy_files_in_descending_order/massive_5.predict"
# massive_7_path="/content/drive/MyDrive/massive_accuracy_files_in_descending_order/massive_0.866.predict"
massive_test_data="/content/drive/MyDrive/massive_accuracy_files_in_descending_order/intent_classification_It_bombay (1)/indoml_iit_bombay/massive_test_phase2_data/massive_test.data"

# %% [markdown]
# #**Here we will concatenate 11 files but the accuracy is different from the above 90.63 which i will write here after the submission**

# %% [markdown]
# # **Loading all the files**

# %%
"we will load the file in the decending order of their accuracy, it means file_1 is the file having max accuracy and file_6 is the file having least accuracy"
import json
import os
import numpy as np
"empty list to store the content of all the files"


file_1_list=[]
file_2_list=[]
file_3_list=[]
file_4_list=[]
file_5_list=[]
file_6_list=[]
file_7_list=[]
file_8_list=[]
file_9_list=[]
file_10_list=[]
file_11_list=[]

test_data_list=[]

"Reading the files"
with open(massive_1_path,'r') as file_1:
  files_1=file_1.readlines()

with open(massive_2_path,'r') as file_2:
  files_2=file_2.readlines()

with open(massive_3_path,'r') as file_3:
  files_3=file_3.readlines()

with open(massive_4_path,'r') as file_4:
  files_4=file_4.readlines()

with open(massive_5_path,'r') as file_5:
  files_5=file_5.readlines()

with open(massive_6_path,'r') as file_6:
  files_6=file_6.readlines()

with open(massive_7_path,'r') as file_7:
  files_7=file_7.readlines()

with open(massive_8_path,'r') as file_8:
  files_8=file_8.readlines()

with open(massive_9_path,'r') as file_9:
  files_9=file_9.readlines()

with open(massive_10_path,'r') as file_10:
  files_10=file_10.readlines()

with open(massive_11_path,'r') as file_11:
  files_11=file_11.readlines()

with open(massive_test_data,'r') as test_1:
  tests_1=test_1.readlines()

"appending the content of the files into list and also converting str content into Object"
for line_1 in files_1:
  line_1=line_1.strip('\n')
  line_1=json.loads(line_1)
  file_1_list.append(line_1)

for line_2 in files_2:
  line_2=line_2.strip('\n')
  line_2=json.loads(line_2)
  file_2_list.append(line_2)

for line_3 in files_3:
  line_3=line_3.strip('\n')
  line_3=json.loads(line_3)
  file_3_list.append(line_3)

for line_4 in files_4:
  line_4=line_4.strip('\n')
  line_4=json.loads(line_4)
  file_4_list.append(line_4)

for line_5 in files_5:
  line_5=line_5.strip('\n')
  line_5=json.loads(line_5)
  file_5_list.append(line_5)

for line_6 in files_6:
  line_6=line_6.strip('\n')
  line_6=json.loads(line_6)
  file_6_list.append(line_6)

for line_7 in files_7:
  line_7=line_7.strip('\n')
  line_7=json.loads(line_7)
  file_7_list.append(line_7)

for line_8 in files_8:
  line_8=line_8.strip('\n')
  line_8=json.loads(line_8)
  file_8_list.append(line_8)


for line_9 in files_9:
  line_9=line_9.strip('\n')
  line_9=json.loads(line_9)
  file_9_list.append(line_9)


for line_10 in files_10:
  line_10=line_10.strip('\n')
  line_10=json.loads(line_10)
  file_10_list.append(line_10)


for line_11 in files_11:
  line_11=line_11.strip('\n')
  line_11=json.loads(line_11)
  file_11_list.append(line_11)

for test_line_1 in tests_1:
  test_line_1=test_line_1.strip('\n')
  test_line_1=json.loads(test_line_1)
  test_data_list.append(test_line_1)

# file_1_list[0], len(file_1_list)

# %%
\
print(file_1_list[0], len(file_1_list))
print(file_2_list[0], len(file_2_list))
print(file_3_list[0], len(file_3_list))
print(file_4_list[0], len(file_4_list))
print(file_5_list[0], len(file_5_list))
print(file_6_list[0], len(file_6_list))
print(file_7_list[0], len(file_7_list))
print(file_8_list[0], len(file_9_list))
print(file_10_list[0], len(file_11_list))

print(test_data_list[0], len(test_data_list))
# Out:
# {'indoml_id': 1, 'intent': 'transactions'} 6000
# {'indoml_id': 1, 'intent': 'transactions'} 6000
# {'indoml_id': 1, 'intent': 'transactions'} 6000
# {'indoml_id': 1, 'intent': 'transactions'} 6000
# {'indoml_id': 1, 'intent': 'transactions'} 6000
# {'indoml_id': 1, 'intent': 'transactions'} 6000
# {'indoml_id': 1, 'intent': 'transactions'} 6000
# {'indoml_id': 1, 'intent': 'transactions'} 6000
# {'indoml_id': 1, 'intent': 'transactions'} 6000
# {'indoml_id': 1, 'utt': 'Kindly show me my entire transaction record from the beginning of this year.'} 6000

# %%
import pandas as pd
file_1_pd=pd.DataFrame.from_dict(file_1_list)
file_1_pd

file_2_pd=pd.DataFrame.from_dict(file_2_list)
file_2_pd

file_3_pd=pd.DataFrame.from_dict(file_3_list)
file_3_pd

file_4_pd=pd.DataFrame.from_dict(file_4_list)
file_4_pd

file_5_pd=pd.DataFrame.from_dict(file_5_list)
file_5_pd

file_6_pd=pd.DataFrame.from_dict(file_6_list)
file_6_pd

file_7_pd=pd.DataFrame.from_dict(file_7_list)
file_7_pd

file_8_pd=pd.DataFrame.from_dict(file_8_list)
file_8_pd

file_9_pd=pd.DataFrame.from_dict(file_9_list)
file_9_pd

file_10_pd=pd.DataFrame.from_dict(file_10_list)
file_10_pd

file_11_pd=pd.DataFrame.from_dict(file_11_list)
file_11_pd

test_data_pd=pd.DataFrame.from_dict(test_data_list)
file_1_pd, file_2_pd, file_3_pd, file_4_pd, file_5_pd, file_6_pd, test_data_pd
# Out:
# (      indoml_id              intent
#  0             1        transactions
#  1             2               order
#  2             3         sync device
#  3             4       interest rate
#  4             5                 yes
#  ...         ...                 ...
#  5995       5996  restaurant reviews
#  5996       5997       exchange rate
#  5997       5998        report fraud
#  5998       5999  restaurant reviews
#  5999       6000              cancel
#
#  [6000 rows x 2 columns],
#        indoml_id              intent
#  0             1        transactions
#  1             2               order
#  2             3         sync device
#  3             4       interest rate
#  4             5       shopping list
#  ...         ...                 ...
#  5995       5996  restaurant reviews
#  5996       5997       exchange rate
#  5997       5998        report fraud
#  5998       5999     meal suggestion
#  5999       6000              cancel
#
#  [6000 rows x 2 columns],
# ...

# %%
file_1_pd.rename(columns={'intent':'intent_1'}, inplace=True)
file_2_pd.rename(columns={'intent':'intent_2'}, inplace=True)
file_3_pd.rename(columns={'intent':'intent_3'}, inplace=True)
file_4_pd.rename(columns={'intent':'intent_4'}, inplace=True)
file_5_pd.rename(columns={'intent':'intent_5'}, inplace=True)
file_6_pd.rename(columns={'intent':'intent_6'}, inplace=True)
file_7_pd.rename(columns={'intent':'intent_7'}, inplace=True)
file_8_pd.rename(columns={'intent':'intent_8'}, inplace=True)
file_9_pd.rename(columns={'intent':'intent_9'}, inplace=True)
file_10_pd.rename(columns={'intent':'intent_10'}, inplace=True)
file_11_pd.rename(columns={'intent':'intent_11'}, inplace=True)

file_1_pd, file_2_pd, file_3_pd, file_4_pd, file_5_pd, file_6_pd, file_7_pd,file_8_pd, file_9_pd, file_10_pd, file_11_pd, test_data_pd
# Out:
# (      indoml_id            intent_1
#  0             1        transactions
#  1             2               order
#  2             3         sync device
#  3             4       interest rate
#  4             5                 yes
#  ...         ...                 ...
#  5995       5996  restaurant reviews
#  5996       5997       exchange rate
#  5997       5998        report fraud
#  5998       5999  restaurant reviews
#  5999       6000              cancel
#
#  [6000 rows x 2 columns],
#        indoml_id            intent_2
#  0             1        transactions
#  1             2               order
#  2             3         sync device
#  3             4       interest rate
#  4             5       shopping list
#  ...         ...                 ...
#  5995       5996  restaurant reviews
#  5996       5997       exchange rate
#  5997       5998        report fraud
#  5998       5999     meal suggestion
#  5999       6000              cancel
#
#  [6000 rows x 2 columns],
# ...

# %%
files_12_pd=pd.merge(file_1_pd, file_2_pd, on='indoml_id', how='left')
files_34_pd=pd.merge(file_3_pd, file_4_pd, on='indoml_id', how='left')
files_56_pd=pd.merge(file_5_pd, file_6_pd, on='indoml_id', how='left')
files_78_pd=pd.merge(file_7_pd, file_8_pd, on='indoml_id', how='left')
files_910_pd=pd.merge(file_9_pd, file_10_pd, on='indoml_id', how='left')
files_1112_pd=pd.merge(file_11_pd, test_data_pd, on='indoml_id', how='left')
files_12_pd, files_34_pd, files_56_pd,files_78_pd,files_910_pd,files_1112_pd
# Out:
# (      indoml_id            intent_1            intent_2
#  0             1        transactions        transactions
#  1             2               order               order
#  2             3         sync device         sync device
#  3             4       interest rate       interest rate
#  4             5                 yes       shopping list
#  ...         ...                 ...                 ...
#  5995       5996  restaurant reviews  restaurant reviews
#  5996       5997       exchange rate       exchange rate
#  5997       5998        report fraud        report fraud
#  5998       5999  restaurant reviews     meal suggestion
#  5999       6000              cancel              cancel
#
#  [6000 rows x 3 columns],
#        indoml_id            intent_3            intent_4
#  0             1        transactions        transactions
#  1             2               order               order
#  2             3         sync device         sync device
# ...

# %%
files_1234_pd=pd.merge(files_12_pd, files_34_pd, on='indoml_id', how='left')
files_5678_pd=pd.merge(files_56_pd, files_78_pd, on='indoml_id', how='left')
files_9101112_pd=pd.merge(files_910_pd, files_1112_pd, on='indoml_id', how='left')
files_1234_pd,files_5678_pd, files_9101112_pd
# Out:
# (      indoml_id            intent_1            intent_2            intent_3  \
#  0             1        transactions        transactions        transactions
#  1             2               order               order               order
#  2             3         sync device         sync device         sync device
#  3             4       interest rate       interest rate       interest rate
#  4             5                 yes       shopping list               order
#  ...         ...                 ...                 ...                 ...
#  5995       5996  restaurant reviews  restaurant reviews  restaurant reviews
#  5996       5997       exchange rate       exchange rate       exchange rate
#  5997       5998        report fraud        report fraud        report fraud
#  5998       5999  restaurant reviews     meal suggestion     meal suggestion
#  5999       6000              cancel              cancel              cancel
#
#                  intent_4
# ...

# %%
files_12345678_pd=pd.merge(files_1234_pd, files_5678_pd, on='indoml_id', how='left')
final_data_pd=pd.merge(files_12345678_pd, files_9101112_pd, on="indoml_id", how='left')
print(final_data_pd.head())
print('\n')
print(final_data_pd.shape)
# Out:
#    indoml_id       intent_1       intent_2       intent_3       intent_4  \
# 0          1   transactions   transactions   transactions   transactions
# 1          2          order          order          order          order
# 2          3    sync device    sync device    sync device    sync device
# 3          4  interest rate  interest rate  interest rate  interest rate
# 4          5            yes  shopping list          order            yes
#
#         intent_5       intent_6       intent_7         intent_8  \
# 0   transactions   transactions   transactions     transactions
# 1          order          order          order            order
# 2    sync device    sync device    sync device      sync device
# 3  interest rate  interest rate  interest rate    interest rate
# 4          order          order            yes  meal suggestion
#
#           intent_9      intent_10        intent_11  \
# 0     transactions   transactions     transactions
# ...

# %%
final_data_pd.head()
# Out:
#    indoml_id       intent_1       intent_2       intent_3       intent_4  \
# 0          1   transactions   transactions   transactions   transactions
# 1          2          order          order          order          order
# 2          3    sync device    sync device    sync device    sync device
# 3          4  interest rate  interest rate  interest rate  interest rate
# 4          5            yes  shopping list          order            yes
#
#         intent_5       intent_6       intent_7         intent_8  \
# 0   transactions   transactions   transactions     transactions
# 1          order          order          order            order
# 2    sync device    sync device    sync device      sync device
# 3  interest rate  interest rate  interest rate    interest rate
# 4          order          order            yes  meal suggestion
#
#           intent_9      intent_10        intent_11  \
# 0     transactions   transactions     transactions
# ...

# %%
# extract the intent columns
intent_columns=['intent_1','intent_2','intent_3','intent_4','intent_5', 'intent_6','intent_7', 'intent_8','intent_9','intent_10','intent_11']
final_data_pd['intent_new']=final_data_pd[intent_columns].mode(axis=1).iloc[:,0]
final_data_pd.loc[final_data_pd[intent_columns].nunique(axis=1)==11, 'intent_new']=final_data_pd['intent_1']
final_data_pd
# Out:
#       indoml_id            intent_1            intent_2            intent_3  \
# 0             1        transactions        transactions        transactions
# 1             2               order               order               order
# 2             3         sync device         sync device         sync device
# 3             4       interest rate       interest rate       interest rate
# 4             5                 yes       shopping list               order
# ...         ...                 ...                 ...                 ...
# 5995       5996  restaurant reviews  restaurant reviews  restaurant reviews
# 5996       5997       exchange rate       exchange rate       exchange rate
# 5997       5998        report fraud        report fraud        report fraud
# 5998       5999  restaurant reviews     meal suggestion     meal suggestion
# 5999       6000              cancel              cancel              cancel
#
# ...

# %%
# final_data_pd.drop(['intent_1','intent_2','intent_3','intent_4','intent_5','intent_6','intent_7','utt'],axis=1,inplace=True)
final_data_pd
# Out:
#       indoml_id            intent_1            intent_2            intent_3  \
# 0             1        transactions        transactions        transactions
# 1             2               order               order               order
# 2             3         sync device         sync device         sync device
# 3             4       interest rate       interest rate       interest rate
# 4             5                 yes       shopping list               order
# ...         ...                 ...                 ...                 ...
# 5995       5996  restaurant reviews  restaurant reviews  restaurant reviews
# 5996       5997       exchange rate       exchange rate       exchange rate
# 5997       5998        report fraud        report fraud        report fraud
# 5998       5999  restaurant reviews     meal suggestion     meal suggestion
# 5999       6000              cancel              cancel              cancel
#
# ...

# %%
final_data_pd.rename(columns={'intent_new':'intent'},inplace=True)
final_data_pd
# Out:
#       indoml_id            intent_1            intent_2            intent_3  \
# 0             1        transactions        transactions        transactions
# 1             2               order               order               order
# 2             3         sync device         sync device         sync device
# 3             4       interest rate       interest rate       interest rate
# 4             5                 yes       shopping list               order
# ...         ...                 ...                 ...                 ...
# 5995       5996  restaurant reviews  restaurant reviews  restaurant reviews
# 5996       5997       exchange rate       exchange rate       exchange rate
# 5997       5998        report fraud        report fraud        report fraud
# 5998       5999  restaurant reviews     meal suggestion     meal suggestion
# 5999       6000              cancel              cancel              cancel
#
# ...

# %%
final_data_pd.to_csv("/content/drive/MyDrive/massive_accuracy_files_in_descending_order/final_11_22:36_time_accuracy_concatnate_output.csv")

# %%
my_id=[]
my_intent1=[]
my_dict_1={}
for i, entry in enumerate(final_data_pd['intent']):
  my_id.append({'indoml_id':i+1, 'intent':final_data_pd['intent'][i]})
  my_intent1.append(final_data_pd['intent'][i])
  my_dict_1['id']=my_id
  my_dict_1['intent1']= my_intent1

my_dict_1_pd=pd.DataFrame.from_dict(my_dict_1)
my_dict_1_pd.head()
# my_id
# Out:
#                                               id          intent1
# 0     {'indoml_id': 1, 'intent': 'transactions'}     transactions
# 1            {'indoml_id': 2, 'intent': 'order'}            order
# 2      {'indoml_id': 3, 'intent': 'sync device'}      sync device
# 3    {'indoml_id': 4, 'intent': 'interest rate'}    interest rate
# 4  {'indoml_id': 5, 'intent': 'meal suggestion'}  meal suggestion

# %%
with open('massive_test_sumit_12_final.predict','w') as out_file:
  for entry in my_dict_1_pd['id']:
    out_file.write(str(entry))
    out_file.write('\n')

# %%
# my_id=[]
# my_intent=[]
# for i, entry in enumerate(test_data_list):
#   my_id.append({'indoml_id':i+1})

# %%
# dict_1={}
# dict_2={}
# dict_3={}
# dict_4={}
# dict_5={}
# dict_6={}

# for entry_1 in file_1_list:
#   if entry_1['intent'] not in dict_1:
#     dict_1[entry_1['intent']]=1
#   else:
#     dict_1[entry_1['intent']]+=1


# for entry_2 in file_2_list:
#   if entry_2['intent'] not in dict_2:
#     dict_2[entry_2['intent']]=1
#   else:
#     dict_2[entry_2['intent']]+=1


# for entry_3 in file_3_list:
#   if entry_3['intent'] not in dict_3:
#     dict_3[entry_3['intent']]=1
#   else:
#     dict_3[entry_3['intent']]+=1


# for entry_4 in file_4_list:
#   if entry_4['intent'] not in dict_4:
#     dict_4[entry_4['intent']]=1
#   else:
#     dict_4[entry_4['intent']]+=1


# for entry_5 in file_5_list:
#   if entry_5['intent'] not in dict_5:
#     dict_5[entry_5['intent']]=1
#   else:
#     dict_5[entry_5['intent']]+=1


# for entry_6 in file_6_list:
#   if entry_6['intent'] not in dict_6:
#     dict_6[entry_6['intent']]=1
#   else:
#     dict_6[entry_6['intent']]+=1

# %%
# !pip install datasets
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 7.8 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset_builder
ds_builder = load_dataset_builder("rotten_tomatoes")

ds_builder.info.description

ds_builder.info.features
# Out:
# ...
# {'text': Value(dtype='string', id=None),
#  'label': ClassLabel(names=['neg', 'pos'], id=None)}
